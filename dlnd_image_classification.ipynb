# %% [markdown]
# # Image Classification
# In this project, you'll classify images from the [CIFAR-10 dataset](https://www.cs.toronto.edu/~kriz/cifar.html).  The dataset consists of airplanes, dogs, cats, and other objects. You'll preprocess the images, then train a convolutional neural network on all the samples. The images need to be normalized and the labels need to be one-hot encoded.  You'll get to apply what you learned and build a convolutional, max pooling, dropout, and fully connected layers.  At the end, you'll get to see your neural network's predictions on the sample images.
# ## Get the Data
# Run the following cell to download the [CIFAR-10 dataset for python](https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz).

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import problem_unittests as tests
import tarfile

cifar10_dataset_folder_path = 'cifar-10-batches-py'

# Use Floyd's cifar-10 dataset if present
floyd_cifar10_location = '/cifar/cifar-10-python.tar.gz'
if isfile(floyd_cifar10_location):
    tar_gz_path = floyd_cifar10_location
else:
    tar_gz_path = 'cifar-10-python.tar.gz'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(tar_gz_path):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc='CIFAR-10 Dataset') as pbar:
        urlretrieve(
            'https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz',
            tar_gz_path,
            pbar.hook)

if not isdir(cifar10_dataset_folder_path):
    with tarfile.open(tar_gz_path) as tar:
        tar.extractall()
        tar.close()


tests.test_folder_path(cifar10_dataset_folder_path)
# Out:
# CIFAR-10 Dataset: 171MB [00:29, 5.79MB/s]
# All files found!

# %% [markdown]
# ## Explore the Data
# The dataset is broken into batches to prevent your machine from running out of memory.  The CIFAR-10 dataset consists of 5 batches, named `data_batch_1`, `data_batch_2`, etc.. Each batch contains the labels and images that are one of the following:
# * airplane
# * automobile
# * bird
# * cat
# * deer
# * dog
# * frog
# * horse
# * ship
# * truck
#
# Understanding a dataset is part of making predictions on the data.  Play around with the code cell below by changing the `batch_id` and `sample_id`. The `batch_id` is the id for a batch (1-5). The `sample_id` is the id for a image and label pair in the batch.
#
# Ask yourself "What are all possible labels?", "What is the range of values for the image data?", "Are the labels in order or random?".  Answers to questions like these will help you preprocess the data and end up with better predictions.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import helper
import numpy as np

# Explore the dataset
batch_id = 2
sample_id = 1
helper.display_stats(cifar10_dataset_folder_path, batch_id, sample_id)
# Out:
# Stats of batch 2:
# Samples: 10000
# Label Counts: {0: 984, 1: 1007, 2: 1010, 3: 995, 4: 1010, 5: 988, 6: 1008, 7: 1026, 8: 987, 9: 985}
# First 20 Labels: [1, 6, 6, 8, 8, 3, 4, 6, 0, 6, 0, 3, 6, 6, 5, 4, 8, 3, 2, 6]
#
# Example of Image 1:
# Image - Min Value: 2 Max Value: 247
# Image - Shape: (32, 32, 3)
# Label - Label Id: 6 Name: frog

# %% [markdown]
# ## Implement Preprocess Functions
# ### Normalize
# In the cell below, implement the `normalize` function to take in image data, `x`, and return it as a normalized Numpy array. The values should be in the range of 0 to 1, inclusive.  The return object should be the same shape as `x`.

# %%
def normalize(x):
    """
    Normalize a list of sample image data in the range of 0 to 1
    : x: List of image data.  The image shape is (32, 32, 3)
    : return: Numpy array of normalize data
    """
    # TODO: Implement Function
    
    maxi = np.max(x)
    mini = np.min(x)
    
    x = x - mini
    x = x * 0.9
    x = x / (maxi - mini)
    
    
    return x


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_normalize(normalize)
# Out:
# Tests Passed

# %% [markdown]
# ### One-hot encode
# Just like the previous code cell, you'll be implementing a function for preprocessing.  This time, you'll implement the `one_hot_encode` function. The input, `x`, are a list of labels.  Implement the function to return the list of labels as One-Hot encoded Numpy array.  The possible values for labels are 0 to 9. The one-hot encoding function should return the same encoding for each value between each call to `one_hot_encode`.  Make sure to save the map of encodings outside the function.
#
# Hint: Don't reinvent the wheel.

# %%
from sklearn.preprocessing import LabelBinarizer

def one_hot_encode(x):
    """
    One hot encode a list of sample labels. Return a one-hot encoded vector for each label.
    : x: List of sample Labels
    : return: Numpy array of one-hot encoded labels
    """
    # TODO: Implement Function
    
    encoder = LabelBinarizer()
    encoder.fit(np.arange(0,10))
    labels = encoder.transform(x)
    
    return labels


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_one_hot_encode(one_hot_encode)
# Out:
# Tests Passed

# %% [markdown]
# ### Randomize Data
# As you saw from exploring the data above, the order of the samples are randomized.  It doesn't hurt to randomize it again, but you don't need to for this dataset.

# %% [markdown]
# ## Preprocess all the data and save it
# Running the code cell below will preprocess all the CIFAR-10 data and save it to file. The code below also uses 10% of the training data for validation.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# Preprocess Training, Validation, and Testing Data
helper.preprocess_and_save_data(cifar10_dataset_folder_path, normalize, one_hot_encode)

# %% [markdown]
# # Check Point
# This is your first checkpoint.  If you ever decide to come back to this notebook or have to restart the notebook, you can start from here.  The preprocessed data has been saved to disk.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import pickle
import problem_unittests as tests
import helper

# Load the Preprocessed Validation data
valid_features, valid_labels = pickle.load(open('preprocess_validation.p', mode='rb'))

# %% [markdown]
# ## Build the network
# For the neural network, you'll build each layer into a function.  Most of the code you've seen has been outside of functions. To test your code more thoroughly, we require that you put each layer in a function.  This allows us to give you better feedback and test for simple mistakes using our unittests before you submit your project.
#
# >**Note:** If you're finding it hard to dedicate enough time for this course each week, we've provided a small shortcut to this part of the project. In the next couple of problems, you'll have the option to use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages to build each layer, except the layers you build in the "Convolutional and Max Pooling Layer" section.  TF Layers is similar to Keras's and TFLearn's abstraction to layers, so it's easy to pickup.
#
# >However, if you would like to get the most out of this course, try to solve all the problems _without_ using anything from the TF Layers packages. You **can** still use classes from other packages that happen to have the same name as ones you find in TF Layers! For example, instead of using the TF Layers version of the `conv2d` class, [tf.layers.conv2d](https://www.tensorflow.org/api_docs/python/tf/layers/conv2d), you would want to use the TF Neural Network version of `conv2d`, [tf.nn.conv2d](https://www.tensorflow.org/api_docs/python/tf/nn/conv2d).
#
# Let's begin!
#
# ### Input
# The neural network needs to read the image data, one-hot encoded labels, and dropout keep probability. Implement the following functions
# * Implement `neural_net_image_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `image_shape` with batch size set to `None`.
#  * Name the TensorFlow placeholder "x" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_label_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `n_classes` with batch size set to `None`.
#  * Name the TensorFlow placeholder "y" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_keep_prob_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder) for dropout keep probability.
#  * Name the TensorFlow placeholder "keep_prob" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
#
# These names will be used at the end of the project to load your saved model.
#
# Note: `None` for shapes in TensorFlow allow for a dynamic size.

# %%
import tensorflow as tf

# %%
def neural_net_image_input(image_shape):
    """
    Return a Tensor for a batch of image input
    : image_shape: Shape of the images
    : return: Tensor for image input.
    """
    # TODO: Implement Function
    
    x = tf.placeholder("float",shape=[None,image_shape[0],image_shape[1],image_shape[2]],name='x')
    
    return x


def neural_net_label_input(n_classes):
    """
    Return a Tensor for a batch of label input
    : n_classes: Number of classes
    : return: Tensor for label input.
    """
    # TODO: Implement Function
    
    y = tf.placeholder("float",shape=[None,n_classes],name = 'y',)
    return y


def neural_net_keep_prob_input():
    """
    Return a Tensor for keep probability
    : return: Tensor for keep probability.
    """
    # TODO: Implement Function
    
    keep_prob = tf.placeholder("float",name = "keep_prob")
    return keep_prob


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tf.reset_default_graph()
tests.test_nn_image_inputs(neural_net_image_input)
tests.test_nn_label_inputs(neural_net_label_input)
tests.test_nn_keep_prob_inputs(neural_net_keep_prob_input)
# Out:
# Image Input Tests Passed.
# Label Input Tests Passed.
# Keep Prob Tests Passed.

# %% [markdown]
# ### Convolution and Max Pooling Layer
# Convolution layers have a lot of success with images. For this code cell, you should implement the function `conv2d_maxpool` to apply convolution then max pooling:
# * Create the weight and bias using `conv_ksize`, `conv_num_outputs` and the shape of `x_tensor`.
# * Apply a convolution to `x_tensor` using weight and `conv_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
# * Add bias
# * Add a nonlinear activation to the convolution.
# * Apply Max Pooling using `pool_ksize` and `pool_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
#
# **Note:** You **can't** use [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) for **this** layer, but you can still use TensorFlow's [Neural Network](https://www.tensorflow.org/api_docs/python/tf/nn) package. You may still use the shortcut option for all the **other** layers.

# %%
def conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides):
    """
    Apply convolution then max pooling to x_tensor
    :param x_tensor: TensorFlow Tensor
    :param conv_num_outputs: Number of outputs for the convolutional layer
    :param conv_ksize: kernal size 2-D Tuple for the convolutional layer
    :param conv_strides: Stride 2-D Tuple for convolution
    :param pool_ksize: kernal size 2-D Tuple for pool
    :param pool_strides: Stride 2-D Tuple for pool
    : return: A tensor that represents convolution and max pooling of x_tensor
    """
    
    # TODO: Implement Function
    weight = tf.Variable(tf.truncated_normal([conv_ksize[0],conv_ksize[1],x_tensor.get_shape().as_list()[3],conv_num_outputs]))
    bias = tf.Variable(tf.random_normal([conv_num_outputs]))
    #convolution
    conv = tf.nn.conv2d(x_tensor,weight,strides=[1,conv_strides[0],conv_strides[1],1],padding="SAME")
    conv = tf.nn.bias_add(conv,bias)
    conv = tf.nn.relu(conv)
    conv = tf.nn.max_pool(conv,ksize=[1,pool_ksize[0],pool_ksize[1],1],strides=[1,pool_strides[0],pool_strides[0],1],padding="SAME")
    return conv


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_con_pool(conv2d_maxpool)
# Out:
# Tests Passed

# %% [markdown]
# ### Flatten Layer
# Implement the `flatten` function to change the dimension of `x_tensor` from a 4-D tensor to a 2-D tensor.  The output should be the shape (*Batch Size*, *Flattened Image Size*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.

# %%
def flatten(x_tensor):
    """
    Flatten x_tensor to (Batch Size, Flattened Image Size)
    : x_tensor: A tensor of size (Batch Size, ...), where ... are the image dimensions.
    : return: A tensor of size (Batch Size, Flattened Image Size).
    """
    # TODO: Implement Function
    
    
    
    new_size = (x_tensor.get_shape().as_list()[1])*(x_tensor.get_shape().as_list()[2])*(x_tensor.get_shape().as_list()[3])
    
    new_tensor =  tf.reshape(x_tensor,shape=[tf.shape(x_tensor)[0],new_size])
    
    return new_tensor


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_flatten(flatten)
# Out:
# Tests Passed

# %% [markdown]
# ### Fully-Connected Layer
# Implement the `fully_conn` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.

# %%
def fully_conn(x_tensor, num_outputs):
    """
    Apply a fully connected layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    
    weight = tf.Variable(tf.truncated_normal([x_tensor.get_shape().as_list()[1],num_outputs]))
    bias = tf.Variable(tf.random_normal([num_outputs]))
    
    # TODO: Implement Function
    
    fc = tf.add(tf.matmul(x_tensor,weight),bias)
    
    return fc


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_fully_conn(fully_conn)
# Out:
# Tests Passed

# %% [markdown]
# ### Output Layer
# Implement the `output` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.
#
# **Note:** Activation, softmax, or cross entropy should **not** be applied to this.

# %%
def output(x_tensor, num_outputs):
    """
    Apply a output layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    # TODO: Implement Function
    
    output = fully_conn(x_tensor,num_outputs)
    
    return output


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_output(output)
# Out:
# Tests Passed

# %% [markdown]
# ### Create Convolutional Model
# Implement the function `conv_net` to create a convolutional neural network model. The function takes in a batch of images, `x`, and outputs logits.  Use the layers you created above to create this model:
#
# * Apply 1, 2, or 3 Convolution and Max Pool layers
# * Apply a Flatten Layer
# * Apply 1, 2, or 3 Fully Connected Layers
# * Apply an Output Layer
# * Return the output
# * Apply [TensorFlow's Dropout](https://www.tensorflow.org/api_docs/python/tf/nn/dropout) to one or more layers in the model using `keep_prob`.

# %%
def conv_net(x, keep_prob):
    """
    Create a convolutional neural network model
    : x: Placeholder tensor that holds image data.
    : keep_prob: Placeholder tensor that hold dropout keep probability.
    : return: Tensor that represents logits
    """
    # TODO: Apply 1, 2, or 3 Convolution and Max Pool layers
    #    Play around with different number of outputs, kernel size and stride
    # Function Definition from Above:
    #    conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides)
    
    conv1 = conv2d_maxpool(x,32,(5,5),(1,1),(2,2),(2,2))
    conv2 = conv2d_maxpool(conv1,128,(5,5),(1,1),(2,2),(2,2))
    conv3 = conv2d_maxpool(conv2,256,(5,5),(1,1),(2,2),(2,2))
    

    # TODO: Apply a Flatten Layer
    # Function Definition from Above:
    #   flatten(x_tensor)
    
    flat_layer = flatten(conv3)
    

    # TODO: Apply 1, 2, or 3 Fully Connected Layers
    #    Play around with different number of outputs
    # Function Definition from Above:
    #   fully_conn(x_tensor, num_outputs)
    
    fc1 = fully_conn(flat_layer,3300)
    fc1 = tf.nn.relu(fc1)
    fc2 = fully_conn(fc1,3000)
    fc2 = tf.nn.relu(fc2)
    fc3 = fully_conn(fc2,2500)
    fc3 = tf.nn.relu(fc3)
    fc3 = tf.nn.dropout(fc3,keep_prob=keep_prob)
    fc2 = tf.nn.dropout(fc2,keep_prob=keep_prob)
    
    # TODO: Apply an Output Layer
    #    Set this to the number of classes
    # Function Definition from Above:
    #   output(x_tensor, num_outputs)
    
    
    # TODO: return output
    
    out = output(fc3,10)
    
    return out


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""

##############################
## Build the Neural Network ##
##############################

# Remove previous weights, bias, inputs, etc..
tf.reset_default_graph()

# Inputs
x = neural_net_image_input((32, 32, 3))
y = neural_net_label_input(10)
keep_prob = neural_net_keep_prob_input()

# Model
logits = conv_net(x, keep_prob)

# Name logits Tensor, so that is can be loaded from disk after training
logits = tf.identity(logits, name='logits')

# Loss and Optimizer
cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=y))
optimizer = tf.train.AdamOptimizer().minimize(cost)

# Accuracy
correct_pred = tf.equal(tf.argmax(logits, 1), tf.argmax(y, 1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32), name='accuracy')

tests.test_conv_net(conv_net)
# Out:
# Neural Network Built!

# %% [markdown]
# ## Train the Neural Network
# ### Single Optimization
# Implement the function `train_neural_network` to do a single optimization.  The optimization should use `optimizer` to optimize in `session` with a `feed_dict` of the following:
# * `x` for image input
# * `y` for labels
# * `keep_prob` for keep probability for dropout
#
# This function will be called for each batch, so `tf.global_variables_initializer()` has already been called.
#
# Note: Nothing needs to be returned. This function is only optimizing the neural network.

# %%
def train_neural_network(session, optimizer, keep_probability, feature_batch, label_batch):
    """
    Optimize the session on a batch of images and labels
    : session: Current TensorFlow session
    : optimizer: TensorFlow optimizer function
    : keep_probability: keep probability
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    """
    # TODO: Implement Function
            
    session.run(optimizer,feed_dict = {keep_prob : keep_probability,x : feature_batch,y : label_batch})
    


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_train_nn(train_neural_network)
# Out:
# Tests Passed

# %% [markdown]
# ### Show Stats
# Implement the function `print_stats` to print loss and validation accuracy.  Use the global variables `valid_features` and `valid_labels` to calculate validation accuracy.  Use a keep probability of `1.0` to calculate the loss and validation accuracy.

# %%
def print_stats(session, feature_batch, label_batch, cost, accuracy):
    """
    Print information about loss and validation accuracy
    : session: Current TensorFlow session
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    : cost: TensorFlow cost function
    : accuracy: TensorFlow accuracy function
    """
    # TODO: Implement Function
    
    loss = session.run(cost,feed_dict = {x : feature_batch , y : label_batch , keep_prob : 1.})
    
    val_accuracy = session.run(accuracy,feed_dict = {x : valid_features , y : valid_labels , keep_prob : 1.})
    
    print("loss :" + str(loss) + "validation accuracy :" + str(val_accuracy))

# %% [markdown]
# ### Hyperparameters
# Tune the following parameters:
# * Set `epochs` to the number of iterations until the network stops learning or start overfitting
# * Set `batch_size` to the highest number that your machine has memory for.  Most people set them to common sizes of memory:
#  * 64
#  * 128
#  * 256
#  * ...
# * Set `keep_probability` to the probability of keeping a node using dropout

# %%
epochs = 200
batch_size = 128
keep_probability = 0.85

# %% [markdown]
# ### Train on a Single CIFAR-10 Batch
# Instead of training the neural network on all the CIFAR-10 batches of data, let's use a single batch. This should save time while you iterate on the model to get a better accuracy.  Once the final validation accuracy is 50% or greater, run the model on all the data in the next section.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
print('Checking the Training on a Single Batch...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        batch_i = 1
        for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
            train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
        print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
        print_stats(sess, batch_features, batch_labels, cost, accuracy)
# Out:
# Checking the Training on a Single Batch...
# Epoch  1, CIFAR-10 Batch 1:  loss :1.18551e+06validation accuracy :0.2712
# Epoch  2, CIFAR-10 Batch 1:  loss :725030.0validation accuracy :0.29
# Epoch  3, CIFAR-10 Batch 1:  loss :624905.0validation accuracy :0.3452
# Epoch  4, CIFAR-10 Batch 1:  loss :552237.0validation accuracy :0.3452
# Epoch  5, CIFAR-10 Batch 1:  loss :416891.0validation accuracy :0.364
# Epoch  6, CIFAR-10 Batch 1:  loss :331884.0validation accuracy :0.3776
# Epoch  7, CIFAR-10 Batch 1:  loss :301754.0validation accuracy :0.3592
# Epoch  8, CIFAR-10 Batch 1:  loss :236748.0validation accuracy :0.37
# Epoch  9, CIFAR-10 Batch 1:  loss :213356.0validation accuracy :0.3216
# Epoch 10, CIFAR-10 Batch 1:  loss :139057.0validation accuracy :0.3368
# Epoch 11, CIFAR-10 Batch 1:  loss :112000.0validation accuracy :0.3904
# Epoch 12, CIFAR-10 Batch 1:  loss :100279.0validation accuracy :0.4096
# Epoch 13, CIFAR-10 Batch 1:  loss :77159.9validation accuracy :0.4218
# Epoch 14, CIFAR-10 Batch 1:  loss :64625.7validation accuracy :0.4184
# Epoch 15, CIFAR-10 Batch 1:  loss :62367.1validation accuracy :0.416
# Epoch 16, CIFAR-10 Batch 1:  loss :53072.4validation accuracy :0.4194
# Epoch 17, CIFAR-10 Batch 1:  loss :37947.0validation accuracy :0.3964
# Epoch 18, CIFAR-10 Batch 1:  loss :39049.4validation accuracy :0.4034
# Epoch 19, CIFAR-10 Batch 1:  loss :8749.52validation accuracy :0.4268
# Epoch 20, CIFAR-10 Batch 1:  loss :31479.0validation accuracy :0.4386
# Epoch 21, CIFAR-10 Batch 1:  loss :17480.6validation accuracy :0.4306
# Epoch 22, CIFAR-10 Batch 1:  loss :13964.9validation accuracy :0.4196
# Epoch 23, CIFAR-10 Batch 1:  loss :2286.9validation accuracy :0.447
# Epoch 24, CIFAR-10 Batch 1:  loss :3524.06validation accuracy :0.4282
# Epoch 25, CIFAR-10 Batch 1:  loss :22053.6validation accuracy :0.4182
# Epoch 26, CIFAR-10 Batch 1:  loss :11695.7validation accuracy :0.4278
# Epoch 27, CIFAR-10 Batch 1:  loss :5878.43validation accuracy :0.4174
# Epoch 28, CIFAR-10 Batch 1:  loss :9119.78validation accuracy :0.4482
# Epoch 29, CIFAR-10 Batch 1:  loss :2251.45validation accuracy :0.4656
# Epoch 30, CIFAR-10 Batch 1:  loss :4112.14validation accuracy :0.4588
# Epoch 31, CIFAR-10 Batch 1:  loss :2379.84validation accuracy :0.4414
# Epoch 32, CIFAR-10 Batch 1:  loss :7499.35validation accuracy :0.4452
# Epoch 33, CIFAR-10 Batch 1:  loss :543.432validation accuracy :0.4424
# Epoch 34, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.4494
# Epoch 35, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.4356
# Epoch 36, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.4248
# Epoch 37, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.4396
# Epoch 38, CIFAR-10 Batch 1:  loss :1345.78validation accuracy :0.44
# Epoch 39, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.457
# Epoch 40, CIFAR-10 Batch 1:  loss :4421.12validation accuracy :0.4312
# Epoch 41, CIFAR-10 Batch 1:  loss :453.464validation accuracy :0.4238
# Epoch 42, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.439
# Epoch 43, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.4692
# Epoch 44, CIFAR-10 Batch 1:  loss :1721.15validation accuracy :0.4576
# Epoch 45, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.4686
# Epoch 46, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.4702
# Epoch 47, CIFAR-10 Batch 1:  loss :264.701validation accuracy :0.4612
# Epoch 48, CIFAR-10 Batch 1:  loss :110.412validation accuracy :0.463
# Epoch 49, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.4564
# Epoch 50, CIFAR-10 Batch 1:  loss :262.867validation accuracy :0.474
# Epoch 51, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.473
# Epoch 52, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.4716
# Epoch 53, CIFAR-10 Batch 1:  loss :580.359validation accuracy :0.4692
# Epoch 54, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.4738
# Epoch 55, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.4698
# Epoch 56, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.4708
# Epoch 57, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.467
# Epoch 58, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.473
# Epoch 59, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.4584
# Epoch 60, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.4678
# Epoch 61, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.4682
# Epoch 62, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.4548
# Epoch 63, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.4508
# Epoch 64, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.4754
# Epoch 65, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.463
# Epoch 66, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.475
# Epoch 67, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.4646
# Epoch 68, CIFAR-10 Batch 1:  loss :384.975validation accuracy :0.45
# Epoch 69, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.472
# Epoch 70, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.4552
# Epoch 71, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.4678
# Epoch 72, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.4642
# Epoch 73, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.4684
# Epoch 74, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.4638
# Epoch 75, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.4678
# Epoch 76, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.4754
# Epoch 77, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.4664
# Epoch 78, CIFAR-10 Batch 1:  loss :2721.06validation accuracy :0.4752
# Epoch 79, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.4702
# Epoch 80, CIFAR-10 Batch 1:  loss :115.728validation accuracy :0.4672
# Epoch 81, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.4736
# Epoch 82, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.4696
# Epoch 83, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.469
# Epoch 84, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.479
# Epoch 85, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.4758
# Epoch 86, CIFAR-10 Batch 1:  loss :251.692validation accuracy :0.4634
# Epoch 87, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.47
# Epoch 88, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.4772
# Epoch 89, CIFAR-10 Batch 1:  loss :1201.16validation accuracy :0.4812
# Epoch 90, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.4908
# Epoch 91, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.4674
# Epoch 92, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.4802
# Epoch 93, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.4692
# Epoch 94, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.4762
# Epoch 95, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.489
# Epoch 96, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.4712
# Epoch 97, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.4928
# Epoch 98, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.492
# Epoch 99, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.4788
# Epoch 100, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.4774
# Epoch 101, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.4816
# Epoch 102, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.4762
# Epoch 103, CIFAR-10 Batch 1:  loss :2249.23validation accuracy :0.4796
# Epoch 104, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.4782
# Epoch 105, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.4906
# Epoch 106, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.4772
# Epoch 107, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.4936
# Epoch 108, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.4912
# Epoch 109, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.4944
# Epoch 110, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.478
# Epoch 111, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.4742
# Epoch 112, CIFAR-10 Batch 1:  loss :4696.4validation accuracy :0.454
# Epoch 113, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.4682
# Epoch 114, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.4628
# Epoch 115, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.4822
# Epoch 116, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.485
# Epoch 117, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.4958
# Epoch 118, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.4776
# Epoch 119, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.4828
# Epoch 120, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.4822
# Epoch 121, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.4858
# Epoch 122, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.4768
# Epoch 123, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.4916
# Epoch 124, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.4974
# Epoch 125, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.5084
# Epoch 126, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.4812
# Epoch 127, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.4972
# Epoch 128, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.4678
# Epoch 129, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.4928
# Epoch 130, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.4752
# Epoch 131, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.4862
# Epoch 132, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.4938
# Epoch 133, CIFAR-10 Batch 1:  loss :389.8validation accuracy :0.4806
# Epoch 134, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.4926
# Epoch 135, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.497
# Epoch 136, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.497
# Epoch 137, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.4962
# Epoch 138, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.499
# Epoch 139, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.5
# Epoch 140, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.5038
# Epoch 141, CIFAR-10 Batch 1:  loss :621.616validation accuracy :0.5034
# Epoch 142, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.5064
# Epoch 143, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.494
# Epoch 144, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.483
# Epoch 145, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.4896
# Epoch 146, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.4982
# Epoch 147, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.4994
# Epoch 148, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.498
# Epoch 149, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.4976
# Epoch 150, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.5034
# Epoch 151, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.4778
# Epoch 152, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.4932
# Epoch 153, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.4964
# Epoch 154, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.502
# Epoch 155, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.4982
# Epoch 156, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.497
# Epoch 157, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.5118
# Epoch 158, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.4922
# Epoch 159, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.5114
# Epoch 160, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.5032
# Epoch 161, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.4974
# Epoch 162, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.495
# Epoch 163, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.5102
# Epoch 164, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.5048
# Epoch 165, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.4992
# Epoch 166, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.5054
# Epoch 167, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.4896
# Epoch 168, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.4936
# Epoch 169, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.5014
# Epoch 170, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.5016
# Epoch 171, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.4958
# Epoch 172, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.5074
# Epoch 173, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.4966
# Epoch 174, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.499
# Epoch 175, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.5004
# Epoch 176, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.4764
# Epoch 177, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.5026
# Epoch 178, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.5106
# Epoch 179, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.5008
# Epoch 180, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.5042
# Epoch 181, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.5064
# Epoch 182, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.5062
# Epoch 183, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.5134
# Epoch 184, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.5106
# Epoch 185, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.4906
# Epoch 186, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.5132
# Epoch 187, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.5116
# Epoch 188, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.5016
# Epoch 189, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.52
# Epoch 190, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.5058
# Epoch 191, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.497
# Epoch 192, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.5212
# Epoch 193, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.5076
# Epoch 194, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.5006
# Epoch 195, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.4992
# Epoch 196, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.4954
# Epoch 197, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.5068
# Epoch 198, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.5116
# Epoch 199, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.5202
# Epoch 200, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.5068

# %% [markdown]
# ### Fully Train the Model
# Now that you got a good accuracy with a single CIFAR-10 batch, try it with all five batches.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
save_model_path = './image_classification'

print('Training...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        # Loop over all batches
        n_batches = 5
        for batch_i in range(1, n_batches + 1):
            for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
                train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
            print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
            print_stats(sess, batch_features, batch_labels, cost, accuracy)
            
    # Save Model
    saver = tf.train.Saver()
    save_path = saver.save(sess, save_model_path)
# Out:
# Training...
# Epoch  1, CIFAR-10 Batch 1:  loss :780170.0validation accuracy :0.2662
# Epoch  1, CIFAR-10 Batch 2:  loss :512998.0validation accuracy :0.306
# Epoch  1, CIFAR-10 Batch 3:  loss :351383.0validation accuracy :0.3338
# Epoch  1, CIFAR-10 Batch 4:  loss :326508.0validation accuracy :0.3518
# Epoch  1, CIFAR-10 Batch 5:  loss :238143.0validation accuracy :0.3732
# Epoch  2, CIFAR-10 Batch 1:  loss :261653.0validation accuracy :0.377
# Epoch  2, CIFAR-10 Batch 2:  loss :277851.0validation accuracy :0.3852
# Epoch  2, CIFAR-10 Batch 3:  loss :179048.0validation accuracy :0.3778
# Epoch  2, CIFAR-10 Batch 4:  loss :116953.0validation accuracy :0.3904
# Epoch  2, CIFAR-10 Batch 5:  loss :203552.0validation accuracy :0.403
# Epoch  3, CIFAR-10 Batch 1:  loss :154248.0validation accuracy :0.3926
# Epoch  3, CIFAR-10 Batch 2:  loss :179198.0validation accuracy :0.3764
# Epoch  3, CIFAR-10 Batch 3:  loss :93174.4validation accuracy :0.396
# Epoch  3, CIFAR-10 Batch 4:  loss :55993.6validation accuracy :0.4148
# Epoch  3, CIFAR-10 Batch 5:  loss :125833.0validation accuracy :0.43
# Epoch  4, CIFAR-10 Batch 1:  loss :99882.8validation accuracy :0.4388
# Epoch  4, CIFAR-10 Batch 2:  loss :101497.0validation accuracy :0.424
# Epoch  4, CIFAR-10 Batch 3:  loss :37944.1validation accuracy :0.4392
# Epoch  4, CIFAR-10 Batch 4:  loss :40114.3validation accuracy :0.4386
# Epoch  4, CIFAR-10 Batch 5:  loss :79915.7validation accuracy :0.4132
# Epoch  5, CIFAR-10 Batch 1:  loss :55642.4validation accuracy :0.4732
# Epoch  5, CIFAR-10 Batch 2:  loss :65159.4validation accuracy :0.453
# Epoch  5, CIFAR-10 Batch 3:  loss :27524.9validation accuracy :0.4272
# Epoch  5, CIFAR-10 Batch 4:  loss :27954.0validation accuracy :0.4516
# Epoch  5, CIFAR-10 Batch 5:  loss :35513.4validation accuracy :0.439
# Epoch  6, CIFAR-10 Batch 1:  loss :38104.3validation accuracy :0.461
# Epoch  6, CIFAR-10 Batch 2:  loss :41425.5validation accuracy :0.4628
# Epoch  6, CIFAR-10 Batch 3:  loss :9410.64validation accuracy :0.4438
# Epoch  6, CIFAR-10 Batch 4:  loss :11352.7validation accuracy :0.4668
# Epoch  6, CIFAR-10 Batch 5:  loss :18104.5validation accuracy :0.4616
# Epoch  7, CIFAR-10 Batch 1:  loss :24781.8validation accuracy :0.4684
# Epoch  7, CIFAR-10 Batch 2:  loss :25624.7validation accuracy :0.462
# Epoch  7, CIFAR-10 Batch 3:  loss :2423.75validation accuracy :0.4574
# Epoch  7, CIFAR-10 Batch 4:  loss :9386.5validation accuracy :0.473
# Epoch  7, CIFAR-10 Batch 5:  loss :15809.5validation accuracy :0.463
# Epoch  8, CIFAR-10 Batch 1:  loss :25936.0validation accuracy :0.4532
# Epoch  8, CIFAR-10 Batch 2:  loss :17535.5validation accuracy :0.4728
# Epoch  8, CIFAR-10 Batch 3:  loss :1924.61validation accuracy :0.479
# Epoch  8, CIFAR-10 Batch 4:  loss :9563.15validation accuracy :0.4606
# Epoch  8, CIFAR-10 Batch 5:  loss :7121.97validation accuracy :0.4678
# Epoch  9, CIFAR-10 Batch 1:  loss :12776.4validation accuracy :0.4588
# Epoch  9, CIFAR-10 Batch 2:  loss :12355.7validation accuracy :0.464
# Epoch  9, CIFAR-10 Batch 3:  loss :2014.13validation accuracy :0.481
# Epoch  9, CIFAR-10 Batch 4:  loss :4839.69validation accuracy :0.4672
# Epoch  9, CIFAR-10 Batch 5:  loss :5403.78validation accuracy :0.4724
# Epoch 10, CIFAR-10 Batch 1:  loss :7791.1validation accuracy :0.4644
# Epoch 10, CIFAR-10 Batch 2:  loss :15468.0validation accuracy :0.4508
# Epoch 10, CIFAR-10 Batch 3:  loss :2984.48validation accuracy :0.4782
# Epoch 10, CIFAR-10 Batch 4:  loss :3336.08validation accuracy :0.4722
# Epoch 10, CIFAR-10 Batch 5:  loss :2826.45validation accuracy :0.4772
# Epoch 11, CIFAR-10 Batch 1:  loss :6298.42validation accuracy :0.4722
# Epoch 11, CIFAR-10 Batch 2:  loss :5481.4validation accuracy :0.4656
# Epoch 11, CIFAR-10 Batch 3:  loss :262.87validation accuracy :0.4806
# Epoch 11, CIFAR-10 Batch 4:  loss :5985.37validation accuracy :0.4704
# Epoch 11, CIFAR-10 Batch 5:  loss :3540.76validation accuracy :0.483
# Epoch 12, CIFAR-10 Batch 1:  loss :7809.73validation accuracy :0.4884
# Epoch 12, CIFAR-10 Batch 2:  loss :5473.75validation accuracy :0.4858
# Epoch 12, CIFAR-10 Batch 3:  loss :410.836validation accuracy :0.4764
# Epoch 12, CIFAR-10 Batch 4:  loss :2816.3validation accuracy :0.4834
# Epoch 12, CIFAR-10 Batch 5:  loss :5033.22validation accuracy :0.4892
# Epoch 13, CIFAR-10 Batch 1:  loss :5327.36validation accuracy :0.4816
# Epoch 13, CIFAR-10 Batch 2:  loss :2993.82validation accuracy :0.4806
# Epoch 13, CIFAR-10 Batch 3:  loss :0.0validation accuracy :0.4858
# Epoch 13, CIFAR-10 Batch 4:  loss :2145.99validation accuracy :0.48
# Epoch 13, CIFAR-10 Batch 5:  loss :4992.21validation accuracy :0.4768
# Epoch 14, CIFAR-10 Batch 1:  loss :997.203validation accuracy :0.4788
# Epoch 14, CIFAR-10 Batch 2:  loss :3351.34validation accuracy :0.4824
# Epoch 14, CIFAR-10 Batch 3:  loss :946.714validation accuracy :0.474
# Epoch 14, CIFAR-10 Batch 4:  loss :3133.07validation accuracy :0.4842
# Epoch 14, CIFAR-10 Batch 5:  loss :2223.26validation accuracy :0.472
# Epoch 15, CIFAR-10 Batch 1:  loss :1832.44validation accuracy :0.4814
# Epoch 15, CIFAR-10 Batch 2:  loss :1997.25validation accuracy :0.4868
# Epoch 15, CIFAR-10 Batch 3:  loss :278.883validation accuracy :0.4776
# Epoch 15, CIFAR-10 Batch 4:  loss :1506.36validation accuracy :0.481
# Epoch 15, CIFAR-10 Batch 5:  loss :1511.9validation accuracy :0.481
# Epoch 16, CIFAR-10 Batch 1:  loss :1504.74validation accuracy :0.49
# Epoch 16, CIFAR-10 Batch 2:  loss :95.3273validation accuracy :0.4978
# Epoch 16, CIFAR-10 Batch 3:  loss :61.5605validation accuracy :0.495
# Epoch 16, CIFAR-10 Batch 4:  loss :368.58validation accuracy :0.4852
# Epoch 16, CIFAR-10 Batch 5:  loss :950.303validation accuracy :0.4864
# Epoch 17, CIFAR-10 Batch 1:  loss :217.452validation accuracy :0.4976
# Epoch 17, CIFAR-10 Batch 2:  loss :820.947validation accuracy :0.4822
# Epoch 17, CIFAR-10 Batch 3:  loss :2562.51validation accuracy :0.4942
# Epoch 17, CIFAR-10 Batch 4:  loss :27.8277validation accuracy :0.496
# Epoch 17, CIFAR-10 Batch 5:  loss :883.37validation accuracy :0.4948
# Epoch 18, CIFAR-10 Batch 1:  loss :604.896validation accuracy :0.5054
# Epoch 18, CIFAR-10 Batch 2:  loss :25.532validation accuracy :0.4856
# Epoch 18, CIFAR-10 Batch 3:  loss :726.595validation accuracy :0.4788
# Epoch 18, CIFAR-10 Batch 4:  loss :1204.16validation accuracy :0.4808
# Epoch 18, CIFAR-10 Batch 5:  loss :343.712validation accuracy :0.4998
# Epoch 19, CIFAR-10 Batch 1:  loss :310.332validation accuracy :0.494
# Epoch 19, CIFAR-10 Batch 2:  loss :403.608validation accuracy :0.4974
# Epoch 19, CIFAR-10 Batch 3:  loss :541.188validation accuracy :0.4896
# Epoch 19, CIFAR-10 Batch 4:  loss :485.992validation accuracy :0.4968
# Epoch 19, CIFAR-10 Batch 5:  loss :971.576validation accuracy :0.4938
# Epoch 20, CIFAR-10 Batch 1:  loss :527.512validation accuracy :0.4936
# Epoch 20, CIFAR-10 Batch 2:  loss :1219.32validation accuracy :0.497
# Epoch 20, CIFAR-10 Batch 3:  loss :259.196validation accuracy :0.4706
# Epoch 20, CIFAR-10 Batch 4:  loss :398.872validation accuracy :0.4852
# Epoch 20, CIFAR-10 Batch 5:  loss :1299.19validation accuracy :0.474
# Epoch 21, CIFAR-10 Batch 1:  loss :57.9998validation accuracy :0.4932
# Epoch 21, CIFAR-10 Batch 2:  loss :407.051validation accuracy :0.4958
# Epoch 21, CIFAR-10 Batch 3:  loss :340.438validation accuracy :0.4808
# Epoch 21, CIFAR-10 Batch 4:  loss :261.078validation accuracy :0.4946
# Epoch 21, CIFAR-10 Batch 5:  loss :0.0validation accuracy :0.49
# Epoch 22, CIFAR-10 Batch 1:  loss :1852.2validation accuracy :0.4958
# Epoch 22, CIFAR-10 Batch 2:  loss :0.0validation accuracy :0.4878
# Epoch 22, CIFAR-10 Batch 3:  loss :312.096validation accuracy :0.4904
# Epoch 22, CIFAR-10 Batch 4:  loss :698.582validation accuracy :0.493
# Epoch 22, CIFAR-10 Batch 5:  loss :400.386validation accuracy :0.5112
# Epoch 23, CIFAR-10 Batch 1:  loss :315.354validation accuracy :0.4996
# Epoch 23, CIFAR-10 Batch 2:  loss :137.568validation accuracy :0.476
# Epoch 23, CIFAR-10 Batch 3:  loss :0.0validation accuracy :0.491
# Epoch 23, CIFAR-10 Batch 4:  loss :59.7229validation accuracy :0.4816
# Epoch 23, CIFAR-10 Batch 5:  loss :402.823validation accuracy :0.5004
# Epoch 24, CIFAR-10 Batch 1:  loss :1020.2validation accuracy :0.4982
# Epoch 24, CIFAR-10 Batch 2:  loss :89.4385validation accuracy :0.4864
# Epoch 24, CIFAR-10 Batch 3:  loss :160.402validation accuracy :0.4964
# Epoch 24, CIFAR-10 Batch 4:  loss :253.851validation accuracy :0.4924
# Epoch 24, CIFAR-10 Batch 5:  loss :771.813validation accuracy :0.4958
# Epoch 25, CIFAR-10 Batch 1:  loss :385.5validation accuracy :0.4982
# Epoch 25, CIFAR-10 Batch 2:  loss :0.0validation accuracy :0.4944
# Epoch 25, CIFAR-10 Batch 3:  loss :0.0validation accuracy :0.4956
# Epoch 25, CIFAR-10 Batch 4:  loss :0.0validation accuracy :0.4954
# Epoch 25, CIFAR-10 Batch 5:  loss :0.0validation accuracy :0.4996
# Epoch 26, CIFAR-10 Batch 1:  loss :175.864validation accuracy :0.4922
# Epoch 26, CIFAR-10 Batch 2:  loss :559.101validation accuracy :0.4842
# Epoch 26, CIFAR-10 Batch 3:  loss :125.197validation accuracy :0.5038
# Epoch 26, CIFAR-10 Batch 4:  loss :131.623validation accuracy :0.4936
# Epoch 26, CIFAR-10 Batch 5:  loss :101.831validation accuracy :0.4926
# Epoch 27, CIFAR-10 Batch 1:  loss :205.122validation accuracy :0.4932
# Epoch 27, CIFAR-10 Batch 2:  loss :155.288validation accuracy :0.4896
# Epoch 27, CIFAR-10 Batch 3:  loss :51.0631validation accuracy :0.4902
# Epoch 27, CIFAR-10 Batch 4:  loss :239.448validation accuracy :0.485
# Epoch 27, CIFAR-10 Batch 5:  loss :249.908validation accuracy :0.4936
# Epoch 28, CIFAR-10 Batch 1:  loss :161.32validation accuracy :0.4942
# Epoch 28, CIFAR-10 Batch 2:  loss :365.293validation accuracy :0.4834
# Epoch 28, CIFAR-10 Batch 3:  loss :252.417validation accuracy :0.4884
# Epoch 28, CIFAR-10 Batch 4:  loss :94.423validation accuracy :0.4996
# Epoch 28, CIFAR-10 Batch 5:  loss :56.4152validation accuracy :0.497
# Epoch 29, CIFAR-10 Batch 1:  loss :791.913validation accuracy :0.495
# Epoch 29, CIFAR-10 Batch 2:  loss :261.608validation accuracy :0.4798
# Epoch 29, CIFAR-10 Batch 3:  loss :56.338validation accuracy :0.4936
# Epoch 29, CIFAR-10 Batch 4:  loss :683.418validation accuracy :0.4972
# Epoch 29, CIFAR-10 Batch 5:  loss :543.227validation accuracy :0.5102
# Epoch 30, CIFAR-10 Batch 1:  loss :466.103validation accuracy :0.5062
# Epoch 30, CIFAR-10 Batch 2:  loss :0.0validation accuracy :0.4776
# Epoch 30, CIFAR-10 Batch 3:  loss :152.728validation accuracy :0.4972
# Epoch 30, CIFAR-10 Batch 4:  loss :74.6055validation accuracy :0.5084
# Epoch 30, CIFAR-10 Batch 5:  loss :0.0validation accuracy :0.5016
# Epoch 31, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.5016
# Epoch 31, CIFAR-10 Batch 2:  loss :37.8593validation accuracy :0.496
# Epoch 31, CIFAR-10 Batch 3:  loss :509.562validation accuracy :0.4968
# Epoch 31, CIFAR-10 Batch 4:  loss :0.0validation accuracy :0.507
# Epoch 31, CIFAR-10 Batch 5:  loss :0.0validation accuracy :0.5066
# Epoch 32, CIFAR-10 Batch 1:  loss :35.9566validation accuracy :0.5128
# Epoch 32, CIFAR-10 Batch 2:  loss :0.0validation accuracy :0.4978
# Epoch 32, CIFAR-10 Batch 3:  loss :0.0validation accuracy :0.5014
# Epoch 32, CIFAR-10 Batch 4:  loss :51.9072validation accuracy :0.505
# Epoch 32, CIFAR-10 Batch 5:  loss :0.0validation accuracy :0.5082
# Epoch 33, CIFAR-10 Batch 1:  loss :540.353validation accuracy :0.5074
# Epoch 33, CIFAR-10 Batch 2:  loss :0.0validation accuracy :0.4926
# Epoch 33, CIFAR-10 Batch 3:  loss :0.0validation accuracy :0.4986
# Epoch 33, CIFAR-10 Batch 4:  loss :74.3797validation accuracy :0.4976
# Epoch 33, CIFAR-10 Batch 5:  loss :258.771validation accuracy :0.5036
# Epoch 34, CIFAR-10 Batch 1:  loss :56.609validation accuracy :0.5104
# Epoch 34, CIFAR-10 Batch 2:  loss :0.0validation accuracy :0.4992
# Epoch 34, CIFAR-10 Batch 3:  loss :95.1152validation accuracy :0.4994
# Epoch 34, CIFAR-10 Batch 4:  loss :0.0validation accuracy :0.504
# Epoch 34, CIFAR-10 Batch 5:  loss :0.0validation accuracy :0.5118
# Epoch 35, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.5
# Epoch 35, CIFAR-10 Batch 2:  loss :20.1011validation accuracy :0.4954
# Epoch 35, CIFAR-10 Batch 3:  loss :0.0validation accuracy :0.5062
# Epoch 35, CIFAR-10 Batch 4:  loss :0.0validation accuracy :0.5074
# Epoch 35, CIFAR-10 Batch 5:  loss :82.3356validation accuracy :0.4992
# Epoch 36, CIFAR-10 Batch 1:  loss :35.2463validation accuracy :0.5066
# Epoch 36, CIFAR-10 Batch 2:  loss :0.0validation accuracy :0.509
# Epoch 36, CIFAR-10 Batch 3:  loss :0.0validation accuracy :0.4934
# Epoch 36, CIFAR-10 Batch 4:  loss :362.374validation accuracy :0.504
# Epoch 36, CIFAR-10 Batch 5:  loss :0.0validation accuracy :0.5108
# Epoch 37, CIFAR-10 Batch 1:  loss :349.352validation accuracy :0.5124
# Epoch 37, CIFAR-10 Batch 2:  loss :0.0validation accuracy :0.5066
# Epoch 37, CIFAR-10 Batch 3:  loss :0.0validation accuracy :0.5032
# Epoch 37, CIFAR-10 Batch 4:  loss :45.073validation accuracy :0.4902
# Epoch 37, CIFAR-10 Batch 5:  loss :54.1453validation accuracy :0.5078
# Epoch 38, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.5096
# Epoch 38, CIFAR-10 Batch 2:  loss :0.0validation accuracy :0.5098
# Epoch 38, CIFAR-10 Batch 3:  loss :0.0validation accuracy :0.513
# Epoch 38, CIFAR-10 Batch 4:  loss :0.0validation accuracy :0.4914
# Epoch 38, CIFAR-10 Batch 5:  loss :0.0validation accuracy :0.5046
# Epoch 39, CIFAR-10 Batch 1:  loss :146.0validation accuracy :0.504
# Epoch 39, CIFAR-10 Batch 2:  loss :0.0validation accuracy :0.5138
# Epoch 39, CIFAR-10 Batch 3:  loss :0.0validation accuracy :0.5118
# Epoch 39, CIFAR-10 Batch 4:  loss :109.992validation accuracy :0.4998
# Epoch 39, CIFAR-10 Batch 5:  loss :32.5596validation accuracy :0.5012
# Epoch 40, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.5166
# Epoch 40, CIFAR-10 Batch 2:  loss :335.975validation accuracy :0.5142
# Epoch 40, CIFAR-10 Batch 3:  loss :0.0validation accuracy :0.5072
# Epoch 40, CIFAR-10 Batch 4:  loss :0.0validation accuracy :0.4992
# Epoch 40, CIFAR-10 Batch 5:  loss :0.0validation accuracy :0.506
# Epoch 41, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.5064
# Epoch 41, CIFAR-10 Batch 2:  loss :74.6387validation accuracy :0.514
# Epoch 41, CIFAR-10 Batch 3:  loss :51.6225validation accuracy :0.5046
# Epoch 41, CIFAR-10 Batch 4:  loss :8.2502validation accuracy :0.4936
# Epoch 41, CIFAR-10 Batch 5:  loss :0.0validation accuracy :0.5036
# Epoch 42, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.5058
# Epoch 42, CIFAR-10 Batch 2:  loss :0.0validation accuracy :0.5126
# Epoch 42, CIFAR-10 Batch 3:  loss :0.0validation accuracy :0.5128
# Epoch 42, CIFAR-10 Batch 4:  loss :0.0validation accuracy :0.4958
# Epoch 42, CIFAR-10 Batch 5:  loss :0.0validation accuracy :0.517
# Epoch 43, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.5152
# Epoch 43, CIFAR-10 Batch 2:  loss :0.0validation accuracy :0.5204
# Epoch 43, CIFAR-10 Batch 3:  loss :145.176validation accuracy :0.5114
# Epoch 43, CIFAR-10 Batch 4:  loss :0.0validation accuracy :0.5002
# Epoch 43, CIFAR-10 Batch 5:  loss :0.0validation accuracy :0.5126
# Epoch 44, CIFAR-10 Batch 1:  loss :2.32012validation accuracy :0.5144
# Epoch 44, CIFAR-10 Batch 2:  loss :0.0validation accuracy :0.5014
# Epoch 44, CIFAR-10 Batch 3:  loss :0.0validation accuracy :0.5036
# Epoch 44, CIFAR-10 Batch 4:  loss :466.208validation accuracy :0.5062
# Epoch 44, CIFAR-10 Batch 5:  loss :0.0validation accuracy :0.5114
# Epoch 45, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.507
# Epoch 45, CIFAR-10 Batch 2:  loss :200.639validation accuracy :0.5114
# Epoch 45, CIFAR-10 Batch 3:  loss :0.0validation accuracy :0.517
# Epoch 45, CIFAR-10 Batch 4:  loss :0.0validation accuracy :0.496
# Epoch 45, CIFAR-10 Batch 5:  loss :0.0validation accuracy :0.5072
# Epoch 46, CIFAR-10 Batch 1:  loss :109.876validation accuracy :0.5096
# Epoch 46, CIFAR-10 Batch 2:  loss :0.0validation accuracy :0.521
# Epoch 46, CIFAR-10 Batch 3:  loss :0.0validation accuracy :0.519
# Epoch 46, CIFAR-10 Batch 4:  loss :0.0validation accuracy :0.5194
# Epoch 46, CIFAR-10 Batch 5:  loss :0.0validation accuracy :0.5094
# Epoch 47, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.5196
# Epoch 47, CIFAR-10 Batch 2:  loss :0.0validation accuracy :0.5158
# Epoch 47, CIFAR-10 Batch 3:  loss :0.0validation accuracy :0.5152
# Epoch 47, CIFAR-10 Batch 4:  loss :312.556validation accuracy :0.5104
# Epoch 47, CIFAR-10 Batch 5:  loss :48.3334validation accuracy :0.5084
# Epoch 48, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.5146
# Epoch 48, CIFAR-10 Batch 2:  loss :0.0validation accuracy :0.5184
# Epoch 48, CIFAR-10 Batch 3:  loss :0.0validation accuracy :0.517
# Epoch 48, CIFAR-10 Batch 4:  loss :0.0validation accuracy :0.511
# Epoch 48, CIFAR-10 Batch 5:  loss :0.0validation accuracy :0.5096
# Epoch 49, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.5174
# Epoch 49, CIFAR-10 Batch 2:  loss :0.0validation accuracy :0.5194
# Epoch 49, CIFAR-10 Batch 3:  loss :0.0validation accuracy :0.516
# Epoch 49, CIFAR-10 Batch 4:  loss :18.1373validation accuracy :0.5136
# Epoch 49, CIFAR-10 Batch 5:  loss :0.0validation accuracy :0.5234
# Epoch 50, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.5178
# Epoch 50, CIFAR-10 Batch 2:  loss :0.0validation accuracy :0.5174
# Epoch 50, CIFAR-10 Batch 3:  loss :0.0validation accuracy :0.5146
# Epoch 50, CIFAR-10 Batch 4:  loss :0.0validation accuracy :0.5152
# Epoch 50, CIFAR-10 Batch 5:  loss :0.0validation accuracy :0.5168
# Epoch 51, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.5148
# Epoch 51, CIFAR-10 Batch 2:  loss :0.0validation accuracy :0.516
# Epoch 51, CIFAR-10 Batch 3:  loss :0.0validation accuracy :0.5122
# Epoch 51, CIFAR-10 Batch 4:  loss :729.831validation accuracy :0.509
# Epoch 51, CIFAR-10 Batch 5:  loss :0.0validation accuracy :0.5054
# Epoch 52, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.5238
# Epoch 52, CIFAR-10 Batch 2:  loss :0.0validation accuracy :0.527
# Epoch 52, CIFAR-10 Batch 3:  loss :0.0validation accuracy :0.5186
# Epoch 52, CIFAR-10 Batch 4:  loss :0.0validation accuracy :0.5108
# Epoch 52, CIFAR-10 Batch 5:  loss :0.0validation accuracy :0.5204
# Epoch 53, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.5254
# Epoch 53, CIFAR-10 Batch 2:  loss :0.0validation accuracy :0.528
# Epoch 53, CIFAR-10 Batch 3:  loss :0.0validation accuracy :0.5332
# Epoch 53, CIFAR-10 Batch 4:  loss :0.0validation accuracy :0.5194
# Epoch 53, CIFAR-10 Batch 5:  loss :0.0validation accuracy :0.5146
# Epoch 54, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.5178
# Epoch 54, CIFAR-10 Batch 2:  loss :0.0validation accuracy :0.5198
# Epoch 54, CIFAR-10 Batch 3:  loss :0.0validation accuracy :0.5362
# Epoch 54, CIFAR-10 Batch 4:  loss :38.0199validation accuracy :0.5126
# Epoch 54, CIFAR-10 Batch 5:  loss :0.0validation accuracy :0.5224
# Epoch 55, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.5292
# Epoch 55, CIFAR-10 Batch 2:  loss :0.0validation accuracy :0.5354
# Epoch 55, CIFAR-10 Batch 3:  loss :0.0validation accuracy :0.5248
# Epoch 55, CIFAR-10 Batch 4:  loss :0.0validation accuracy :0.5196
# Epoch 55, CIFAR-10 Batch 5:  loss :0.0validation accuracy :0.5284
# Epoch 56, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.5228
# Epoch 56, CIFAR-10 Batch 2:  loss :0.0validation accuracy :0.5248
# Epoch 56, CIFAR-10 Batch 3:  loss :0.0validation accuracy :0.5238
# Epoch 56, CIFAR-10 Batch 4:  loss :0.0validation accuracy :0.521
# Epoch 56, CIFAR-10 Batch 5:  loss :0.0validation accuracy :0.5208
# Epoch 57, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.5292
# Epoch 57, CIFAR-10 Batch 2:  loss :0.0validation accuracy :0.5316
# Epoch 57, CIFAR-10 Batch 3:  loss :0.0validation accuracy :0.5312
# Epoch 57, CIFAR-10 Batch 4:  loss :3.05117validation accuracy :0.523
# Epoch 57, CIFAR-10 Batch 5:  loss :0.0validation accuracy :0.5208
# Epoch 58, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.5176
# Epoch 58, CIFAR-10 Batch 2:  loss :0.0validation accuracy :0.5318
# Epoch 58, CIFAR-10 Batch 3:  loss :0.0validation accuracy :0.533
# Epoch 58, CIFAR-10 Batch 4:  loss :96.3852validation accuracy :0.524
# Epoch 58, CIFAR-10 Batch 5:  loss :0.0validation accuracy :0.5252
# Epoch 59, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.534
# Epoch 59, CIFAR-10 Batch 2:  loss :0.0validation accuracy :0.5304
# Epoch 59, CIFAR-10 Batch 3:  loss :0.0validation accuracy :0.5298
# Epoch 59, CIFAR-10 Batch 4:  loss :0.0validation accuracy :0.5258
# Epoch 59, CIFAR-10 Batch 5:  loss :0.0validation accuracy :0.5332
# Epoch 60, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.5276
# Epoch 60, CIFAR-10 Batch 2:  loss :0.0validation accuracy :0.5342
# Epoch 60, CIFAR-10 Batch 3:  loss :0.0validation accuracy :0.5326
# Epoch 60, CIFAR-10 Batch 4:  loss :0.0validation accuracy :0.529
# Epoch 60, CIFAR-10 Batch 5:  loss :0.0validation accuracy :0.5288
# Epoch 61, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.5288
# Epoch 61, CIFAR-10 Batch 2:  loss :0.0validation accuracy :0.5328
# Epoch 61, CIFAR-10 Batch 3:  loss :0.0validation accuracy :0.5242
# Epoch 61, CIFAR-10 Batch 4:  loss :0.0validation accuracy :0.5144
# Epoch 61, CIFAR-10 Batch 5:  loss :0.0validation accuracy :0.5224
# Epoch 62, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.5218
# Epoch 62, CIFAR-10 Batch 2:  loss :0.0validation accuracy :0.5248
# Epoch 62, CIFAR-10 Batch 3:  loss :50.3474validation accuracy :0.5214
# Epoch 62, CIFAR-10 Batch 4:  loss :0.0validation accuracy :0.5268
# Epoch 62, CIFAR-10 Batch 5:  loss :0.0validation accuracy :0.5306
# Epoch 63, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.5176
# Epoch 63, CIFAR-10 Batch 2:  loss :46.882validation accuracy :0.5256
# Epoch 63, CIFAR-10 Batch 3:  loss :0.0validation accuracy :0.5384
# Epoch 63, CIFAR-10 Batch 4:  loss :0.0validation accuracy :0.5208
# Epoch 63, CIFAR-10 Batch 5:  loss :0.0validation accuracy :0.5284
# Epoch 64, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.5198
# Epoch 64, CIFAR-10 Batch 2:  loss :0.0validation accuracy :0.5278
# Epoch 64, CIFAR-10 Batch 3:  loss :0.0validation accuracy :0.5348
# Epoch 64, CIFAR-10 Batch 4:  loss :0.0validation accuracy :0.522
# Epoch 64, CIFAR-10 Batch 5:  loss :0.0validation accuracy :0.527
# Epoch 65, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.5304
# Epoch 65, CIFAR-10 Batch 2:  loss :0.0validation accuracy :0.5254
# Epoch 65, CIFAR-10 Batch 3:  loss :0.0validation accuracy :0.5346
# Epoch 65, CIFAR-10 Batch 4:  loss :0.0validation accuracy :0.5206
# Epoch 65, CIFAR-10 Batch 5:  loss :0.0validation accuracy :0.5194
# Epoch 66, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.5302
# Epoch 66, CIFAR-10 Batch 2:  loss :0.0validation accuracy :0.5384
# Epoch 66, CIFAR-10 Batch 3:  loss :0.0validation accuracy :0.5398
# Epoch 66, CIFAR-10 Batch 4:  loss :0.0validation accuracy :0.5348
# Epoch 66, CIFAR-10 Batch 5:  loss :0.0validation accuracy :0.5224
# Epoch 67, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.5258
# Epoch 67, CIFAR-10 Batch 2:  loss :0.0validation accuracy :0.5332
# Epoch 67, CIFAR-10 Batch 3:  loss :0.0validation accuracy :0.5286
# Epoch 67, CIFAR-10 Batch 4:  loss :0.0validation accuracy :0.5298
# Epoch 67, CIFAR-10 Batch 5:  loss :0.0validation accuracy :0.5386
# Epoch 68, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.5302
# Epoch 68, CIFAR-10 Batch 2:  loss :0.0validation accuracy :0.537
# Epoch 68, CIFAR-10 Batch 3:  loss :0.0validation accuracy :0.5342
# Epoch 68, CIFAR-10 Batch 4:  loss :201.164validation accuracy :0.537
# Epoch 68, CIFAR-10 Batch 5:  loss :0.0validation accuracy :0.5292
# Epoch 69, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.5158
# Epoch 69, CIFAR-10 Batch 2:  loss :0.0validation accuracy :0.5384
# Epoch 69, CIFAR-10 Batch 3:  loss :0.0validation accuracy :0.5362
# Epoch 69, CIFAR-10 Batch 4:  loss :0.0validation accuracy :0.5294
# Epoch 69, CIFAR-10 Batch 5:  loss :0.0validation accuracy :0.5386
# Epoch 70, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.5432
# Epoch 70, CIFAR-10 Batch 2:  loss :0.0validation accuracy :0.5378
# Epoch 70, CIFAR-10 Batch 3:  loss :0.0validation accuracy :0.5396
# Epoch 70, CIFAR-10 Batch 4:  loss :0.0validation accuracy :0.5322
# Epoch 70, CIFAR-10 Batch 5:  loss :0.0validation accuracy :0.5384
# Epoch 71, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.5366
# Epoch 71, CIFAR-10 Batch 2:  loss :0.0validation accuracy :0.5288
# Epoch 71, CIFAR-10 Batch 3:  loss :0.0validation accuracy :0.531
# Epoch 71, CIFAR-10 Batch 4:  loss :3.3625validation accuracy :0.5422
# Epoch 71, CIFAR-10 Batch 5:  loss :0.0validation accuracy :0.5364
# Epoch 72, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.545
# Epoch 72, CIFAR-10 Batch 2:  loss :0.0validation accuracy :0.5334
# Epoch 72, CIFAR-10 Batch 3:  loss :0.0validation accuracy :0.5336
# Epoch 72, CIFAR-10 Batch 4:  loss :0.0validation accuracy :0.5214
# Epoch 72, CIFAR-10 Batch 5:  loss :0.0validation accuracy :0.5236
# Epoch 73, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.5266
# Epoch 73, CIFAR-10 Batch 2:  loss :0.0validation accuracy :0.5392
# Epoch 73, CIFAR-10 Batch 3:  loss :100.327validation accuracy :0.5392
# Epoch 73, CIFAR-10 Batch 4:  loss :0.0validation accuracy :0.5288
# Epoch 73, CIFAR-10 Batch 5:  loss :0.0validation accuracy :0.5352
# Epoch 74, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.547
# Epoch 74, CIFAR-10 Batch 2:  loss :0.0validation accuracy :0.5286
# Epoch 74, CIFAR-10 Batch 3:  loss :0.0validation accuracy :0.537
# Epoch 74, CIFAR-10 Batch 4:  loss :0.0validation accuracy :0.5404
# Epoch 74, CIFAR-10 Batch 5:  loss :0.0validation accuracy :0.5424
# Epoch 75, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.5498
# Epoch 75, CIFAR-10 Batch 2:  loss :0.0validation accuracy :0.5434
# Epoch 75, CIFAR-10 Batch 3:  loss :0.0validation accuracy :0.5412
# Epoch 75, CIFAR-10 Batch 4:  loss :0.0validation accuracy :0.5296
# Epoch 75, CIFAR-10 Batch 5:  loss :0.0validation accuracy :0.536
# Epoch 76, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.5448
# Epoch 76, CIFAR-10 Batch 2:  loss :0.0validation accuracy :0.5388
# Epoch 76, CIFAR-10 Batch 3:  loss :0.0validation accuracy :0.5314
# Epoch 76, CIFAR-10 Batch 4:  loss :0.0validation accuracy :0.5346
# Epoch 76, CIFAR-10 Batch 5:  loss :0.0validation accuracy :0.5338
# Epoch 77, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.5394
# Epoch 77, CIFAR-10 Batch 2:  loss :0.0validation accuracy :0.533
# Epoch 77, CIFAR-10 Batch 3:  loss :0.0validation accuracy :0.5424
# Epoch 77, CIFAR-10 Batch 4:  loss :0.0validation accuracy :0.5398
# Epoch 77, CIFAR-10 Batch 5:  loss :0.0validation accuracy :0.538
# Epoch 78, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.534
# Epoch 78, CIFAR-10 Batch 2:  loss :0.0validation accuracy :0.5376
# Epoch 78, CIFAR-10 Batch 3:  loss :0.0validation accuracy :0.546
# Epoch 78, CIFAR-10 Batch 4:  loss :0.0validation accuracy :0.5454
# Epoch 78, CIFAR-10 Batch 5:  loss :384.808validation accuracy :0.5346
# Epoch 79, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.5408
# Epoch 79, CIFAR-10 Batch 2:  loss :0.0validation accuracy :0.5394
# Epoch 79, CIFAR-10 Batch 3:  loss :0.0validation accuracy :0.5452
# Epoch 79, CIFAR-10 Batch 4:  loss :166.274validation accuracy :0.5348
# Epoch 79, CIFAR-10 Batch 5:  loss :0.0validation accuracy :0.5436
# Epoch 80, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.5388
# Epoch 80, CIFAR-10 Batch 2:  loss :0.0validation accuracy :0.5346
# Epoch 80, CIFAR-10 Batch 3:  loss :0.0validation accuracy :0.5442
# Epoch 80, CIFAR-10 Batch 4:  loss :0.0validation accuracy :0.5338
# Epoch 80, CIFAR-10 Batch 5:  loss :0.0validation accuracy :0.5372
# Epoch 81, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.5384
# Epoch 81, CIFAR-10 Batch 2:  loss :0.0validation accuracy :0.5382
# Epoch 81, CIFAR-10 Batch 3:  loss :0.0validation accuracy :0.5392
# Epoch 81, CIFAR-10 Batch 4:  loss :0.0validation accuracy :0.5378
# Epoch 81, CIFAR-10 Batch 5:  loss :0.0validation accuracy :0.539
# Epoch 82, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.5478
# Epoch 82, CIFAR-10 Batch 2:  loss :0.0validation accuracy :0.5426
# Epoch 82, CIFAR-10 Batch 3:  loss :0.0validation accuracy :0.5486
# Epoch 82, CIFAR-10 Batch 4:  loss :8.9793validation accuracy :0.5396
# Epoch 82, CIFAR-10 Batch 5:  loss :0.0validation accuracy :0.5358
# Epoch 83, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.5392
# Epoch 83, CIFAR-10 Batch 2:  loss :0.0validation accuracy :0.5466
# Epoch 83, CIFAR-10 Batch 3:  loss :0.0validation accuracy :0.5426
# Epoch 83, CIFAR-10 Batch 4:  loss :9.10156validation accuracy :0.535
# Epoch 83, CIFAR-10 Batch 5:  loss :0.0validation accuracy :0.529
# Epoch 84, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.5508
# Epoch 84, CIFAR-10 Batch 2:  loss :0.0validation accuracy :0.5376
# Epoch 84, CIFAR-10 Batch 3:  loss :0.0validation accuracy :0.543
# Epoch 84, CIFAR-10 Batch 4:  loss :0.0validation accuracy :0.5346
# Epoch 84, CIFAR-10 Batch 5:  loss :0.0validation accuracy :0.5404
# Epoch 85, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.5394
# Epoch 85, CIFAR-10 Batch 2:  loss :0.0validation accuracy :0.5498
# Epoch 85, CIFAR-10 Batch 3:  loss :0.0validation accuracy :0.5424
# Epoch 85, CIFAR-10 Batch 4:  loss :0.0validation accuracy :0.5396
# Epoch 85, CIFAR-10 Batch 5:  loss :0.0validation accuracy :0.5328
# Epoch 86, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.54
# Epoch 86, CIFAR-10 Batch 2:  loss :0.0validation accuracy :0.5406
# Epoch 86, CIFAR-10 Batch 3:  loss :0.0validation accuracy :0.5512
# Epoch 86, CIFAR-10 Batch 4:  loss :0.0validation accuracy :0.547
# Epoch 86, CIFAR-10 Batch 5:  loss :0.0validation accuracy :0.542
# Epoch 87, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.5526
# Epoch 87, CIFAR-10 Batch 2:  loss :0.0validation accuracy :0.5416
# Epoch 87, CIFAR-10 Batch 3:  loss :0.0validation accuracy :0.5324
# Epoch 87, CIFAR-10 Batch 4:  loss :22.5961validation accuracy :0.5428
# Epoch 87, CIFAR-10 Batch 5:  loss :0.0validation accuracy :0.5374
# Epoch 88, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.543
# Epoch 88, CIFAR-10 Batch 2:  loss :0.0validation accuracy :0.5374
# Epoch 88, CIFAR-10 Batch 3:  loss :0.0validation accuracy :0.5346
# Epoch 88, CIFAR-10 Batch 4:  loss :0.0validation accuracy :0.5388
# Epoch 88, CIFAR-10 Batch 5:  loss :0.0validation accuracy :0.537
# Epoch 89, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.5442
# Epoch 89, CIFAR-10 Batch 2:  loss :0.0validation accuracy :0.544
# Epoch 89, CIFAR-10 Batch 3:  loss :0.0validation accuracy :0.5416
# Epoch 89, CIFAR-10 Batch 4:  loss :0.0validation accuracy :0.5436
# Epoch 89, CIFAR-10 Batch 5:  loss :0.0validation accuracy :0.5476
# Epoch 90, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.5474
# Epoch 90, CIFAR-10 Batch 2:  loss :0.0validation accuracy :0.5432
# Epoch 90, CIFAR-10 Batch 3:  loss :0.0validation accuracy :0.5326
# Epoch 90, CIFAR-10 Batch 4:  loss :0.0validation accuracy :0.5382
# Epoch 90, CIFAR-10 Batch 5:  loss :0.0validation accuracy :0.543
# Epoch 91, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.5424
# Epoch 91, CIFAR-10 Batch 2:  loss :0.0validation accuracy :0.5436
# Epoch 91, CIFAR-10 Batch 3:  loss :0.0validation accuracy :0.542
# Epoch 91, CIFAR-10 Batch 4:  loss :0.0validation accuracy :0.5354
# Epoch 91, CIFAR-10 Batch 5:  loss :0.0validation accuracy :0.5496
# Epoch 92, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.551
# Epoch 92, CIFAR-10 Batch 2:  loss :0.0validation accuracy :0.5436
# Epoch 92, CIFAR-10 Batch 3:  loss :0.0validation accuracy :0.5454
# Epoch 92, CIFAR-10 Batch 4:  loss :0.0validation accuracy :0.5522
# Epoch 92, CIFAR-10 Batch 5:  loss :0.0validation accuracy :0.5504
# Epoch 93, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.5426
# Epoch 93, CIFAR-10 Batch 2:  loss :0.0validation accuracy :0.5448
# Epoch 93, CIFAR-10 Batch 3:  loss :0.0validation accuracy :0.5576
# Epoch 93, CIFAR-10 Batch 4:  loss :0.0validation accuracy :0.5496
# Epoch 93, CIFAR-10 Batch 5:  loss :87.8848validation accuracy :0.5492
# Epoch 94, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.552
# Epoch 94, CIFAR-10 Batch 2:  loss :0.0validation accuracy :0.547
# Epoch 94, CIFAR-10 Batch 3:  loss :0.0validation accuracy :0.5404
# Epoch 94, CIFAR-10 Batch 4:  loss :0.0validation accuracy :0.5408
# Epoch 94, CIFAR-10 Batch 5:  loss :0.0validation accuracy :0.5508
# Epoch 95, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.544
# Epoch 95, CIFAR-10 Batch 2:  loss :0.0validation accuracy :0.5436
# Epoch 95, CIFAR-10 Batch 3:  loss :0.0validation accuracy :0.552
# Epoch 95, CIFAR-10 Batch 4:  loss :0.0validation accuracy :0.549
# Epoch 95, CIFAR-10 Batch 5:  loss :0.0validation accuracy :0.5426
# Epoch 96, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.5556
# Epoch 96, CIFAR-10 Batch 2:  loss :0.0validation accuracy :0.5522
# Epoch 96, CIFAR-10 Batch 3:  loss :0.0validation accuracy :0.539
# Epoch 96, CIFAR-10 Batch 4:  loss :0.0validation accuracy :0.5438
# Epoch 96, CIFAR-10 Batch 5:  loss :0.0validation accuracy :0.5466
# Epoch 97, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.5474
# Epoch 97, CIFAR-10 Batch 2:  loss :103.096validation accuracy :0.5478
# Epoch 97, CIFAR-10 Batch 3:  loss :0.0validation accuracy :0.5488
# Epoch 97, CIFAR-10 Batch 4:  loss :0.0validation accuracy :0.5446
# Epoch 97, CIFAR-10 Batch 5:  loss :0.0validation accuracy :0.5492
# Epoch 98, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.547
# Epoch 98, CIFAR-10 Batch 2:  loss :0.0validation accuracy :0.5432
# Epoch 98, CIFAR-10 Batch 3:  loss :0.0validation accuracy :0.5436
# Epoch 98, CIFAR-10 Batch 4:  loss :0.0validation accuracy :0.537
# Epoch 98, CIFAR-10 Batch 5:  loss :0.0validation accuracy :0.5386
# Epoch 99, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.5514
# Epoch 99, CIFAR-10 Batch 2:  loss :0.0validation accuracy :0.5496
# Epoch 99, CIFAR-10 Batch 3:  loss :0.0validation accuracy :0.5422
# Epoch 99, CIFAR-10 Batch 4:  loss :0.0validation accuracy :0.5414
# Epoch 99, CIFAR-10 Batch 5:  loss :0.0validation accuracy :0.5432
# Epoch 100, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.542
# Epoch 100, CIFAR-10 Batch 2:  loss :0.0validation accuracy :0.5482
# Epoch 100, CIFAR-10 Batch 3:  loss :0.0validation accuracy :0.5452
# Epoch 100, CIFAR-10 Batch 4:  loss :0.0validation accuracy :0.5512
# Epoch 100, CIFAR-10 Batch 5:  loss :0.0validation accuracy :0.5466
# Epoch 101, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.5486
# Epoch 101, CIFAR-10 Batch 2:  loss :0.0validation accuracy :0.5504
# Epoch 101, CIFAR-10 Batch 3:  loss :0.0validation accuracy :0.5448
# Epoch 101, CIFAR-10 Batch 4:  loss :0.0validation accuracy :0.5546
# Epoch 101, CIFAR-10 Batch 5:  loss :0.0validation accuracy :0.554
# Epoch 102, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.5506
# Epoch 102, CIFAR-10 Batch 2:  loss :0.0validation accuracy :0.547
# Epoch 102, CIFAR-10 Batch 3:  loss :0.0validation accuracy :0.552
# Epoch 102, CIFAR-10 Batch 4:  loss :0.0validation accuracy :0.5486
# Epoch 102, CIFAR-10 Batch 5:  loss :0.0validation accuracy :0.559
# Epoch 103, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.5564
# Epoch 103, CIFAR-10 Batch 2:  loss :0.0validation accuracy :0.5604
# Epoch 103, CIFAR-10 Batch 3:  loss :0.0validation accuracy :0.5534
# Epoch 103, CIFAR-10 Batch 4:  loss :0.0validation accuracy :0.5508
# Epoch 103, CIFAR-10 Batch 5:  loss :0.0validation accuracy :0.5354
# Epoch 104, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.546
# Epoch 104, CIFAR-10 Batch 2:  loss :0.0validation accuracy :0.5496
# Epoch 104, CIFAR-10 Batch 3:  loss :0.0validation accuracy :0.5472
# Epoch 104, CIFAR-10 Batch 4:  loss :0.0validation accuracy :0.5546
# Epoch 104, CIFAR-10 Batch 5:  loss :0.0validation accuracy :0.5544
# Epoch 105, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.558
# Epoch 105, CIFAR-10 Batch 2:  loss :0.0validation accuracy :0.5506
# Epoch 105, CIFAR-10 Batch 3:  loss :0.0validation accuracy :0.5516
# Epoch 105, CIFAR-10 Batch 4:  loss :0.0validation accuracy :0.5412
# Epoch 105, CIFAR-10 Batch 5:  loss :0.0validation accuracy :0.5544
# Epoch 106, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.5554
# Epoch 106, CIFAR-10 Batch 2:  loss :0.0validation accuracy :0.5522
# Epoch 106, CIFAR-10 Batch 3:  loss :0.0validation accuracy :0.5568
# Epoch 106, CIFAR-10 Batch 4:  loss :0.0validation accuracy :0.5406
# Epoch 106, CIFAR-10 Batch 5:  loss :0.0validation accuracy :0.5478
# Epoch 107, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.5526
# Epoch 107, CIFAR-10 Batch 2:  loss :0.0validation accuracy :0.5476
# Epoch 107, CIFAR-10 Batch 3:  loss :0.0validation accuracy :0.5496
# Epoch 107, CIFAR-10 Batch 4:  loss :0.0validation accuracy :0.5452
# Epoch 107, CIFAR-10 Batch 5:  loss :0.0validation accuracy :0.5504
# Epoch 108, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.5492
# Epoch 108, CIFAR-10 Batch 2:  loss :0.0validation accuracy :0.5398
# Epoch 108, CIFAR-10 Batch 3:  loss :0.0validation accuracy :0.5426
# Epoch 108, CIFAR-10 Batch 4:  loss :0.0validation accuracy :0.5476
# Epoch 108, CIFAR-10 Batch 5:  loss :73.7344validation accuracy :0.5602
# Epoch 109, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.5572
# Epoch 109, CIFAR-10 Batch 2:  loss :0.0validation accuracy :0.5562
# Epoch 109, CIFAR-10 Batch 3:  loss :0.0validation accuracy :0.5448
# Epoch 109, CIFAR-10 Batch 4:  loss :0.0validation accuracy :0.545
# Epoch 109, CIFAR-10 Batch 5:  loss :0.0validation accuracy :0.5472
# Epoch 110, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.5438
# Epoch 110, CIFAR-10 Batch 2:  loss :75.5863validation accuracy :0.5654
# Epoch 110, CIFAR-10 Batch 3:  loss :0.0validation accuracy :0.5478
# Epoch 110, CIFAR-10 Batch 4:  loss :0.0validation accuracy :0.5544
# Epoch 110, CIFAR-10 Batch 5:  loss :0.0validation accuracy :0.5454
# Epoch 111, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.5546
# Epoch 111, CIFAR-10 Batch 2:  loss :209.688validation accuracy :0.5572
# Epoch 111, CIFAR-10 Batch 3:  loss :0.0validation accuracy :0.5462
# Epoch 111, CIFAR-10 Batch 4:  loss :0.0validation accuracy :0.5556
# Epoch 111, CIFAR-10 Batch 5:  loss :0.0validation accuracy :0.5562
# Epoch 112, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.5566
# Epoch 112, CIFAR-10 Batch 2:  loss :0.0validation accuracy :0.5496
# Epoch 112, CIFAR-10 Batch 3:  loss :0.0validation accuracy :0.5512
# Epoch 112, CIFAR-10 Batch 4:  loss :0.0validation accuracy :0.5588
# Epoch 112, CIFAR-10 Batch 5:  loss :0.0validation accuracy :0.5568
# Epoch 113, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.555
# Epoch 113, CIFAR-10 Batch 2:  loss :0.0validation accuracy :0.5518
# Epoch 113, CIFAR-10 Batch 3:  loss :0.0validation accuracy :0.5676
# Epoch 113, CIFAR-10 Batch 4:  loss :0.0validation accuracy :0.562
# Epoch 113, CIFAR-10 Batch 5:  loss :0.0validation accuracy :0.5448
# Epoch 114, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.5552
# Epoch 114, CIFAR-10 Batch 2:  loss :0.0validation accuracy :0.554
# Epoch 114, CIFAR-10 Batch 3:  loss :0.0validation accuracy :0.5658
# Epoch 114, CIFAR-10 Batch 4:  loss :0.0validation accuracy :0.5584
# Epoch 114, CIFAR-10 Batch 5:  loss :0.0validation accuracy :0.5604
# Epoch 115, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.5556
# Epoch 115, CIFAR-10 Batch 2:  loss :0.0validation accuracy :0.5572
# Epoch 115, CIFAR-10 Batch 3:  loss :0.0validation accuracy :0.5464
# Epoch 115, CIFAR-10 Batch 4:  loss :0.538281validation accuracy :0.5544
# Epoch 115, CIFAR-10 Batch 5:  loss :0.0validation accuracy :0.5536
# Epoch 116, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.5632
# Epoch 116, CIFAR-10 Batch 2:  loss :0.0validation accuracy :0.548
# Epoch 116, CIFAR-10 Batch 3:  loss :0.0validation accuracy :0.5508
# Epoch 116, CIFAR-10 Batch 4:  loss :0.0validation accuracy :0.5568
# Epoch 116, CIFAR-10 Batch 5:  loss :0.0validation accuracy :0.5508
# Epoch 117, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.5582
# Epoch 117, CIFAR-10 Batch 2:  loss :0.0validation accuracy :0.5592
# Epoch 117, CIFAR-10 Batch 3:  loss :0.0validation accuracy :0.5648
# Epoch 117, CIFAR-10 Batch 4:  loss :0.0validation accuracy :0.5584
# Epoch 117, CIFAR-10 Batch 5:  loss :0.0validation accuracy :0.5566
# Epoch 118, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.5568
# Epoch 118, CIFAR-10 Batch 2:  loss :0.0validation accuracy :0.563
# Epoch 118, CIFAR-10 Batch 3:  loss :0.0validation accuracy :0.5518
# Epoch 118, CIFAR-10 Batch 4:  loss :0.0validation accuracy :0.5546
# Epoch 118, CIFAR-10 Batch 5:  loss :0.0validation accuracy :0.5566
# Epoch 119, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.5602
# Epoch 119, CIFAR-10 Batch 2:  loss :0.0validation accuracy :0.5626
# Epoch 119, CIFAR-10 Batch 3:  loss :0.0validation accuracy :0.5468
# Epoch 119, CIFAR-10 Batch 4:  loss :0.0validation accuracy :0.5628
# Epoch 119, CIFAR-10 Batch 5:  loss :0.0validation accuracy :0.5612
# Epoch 120, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.558
# Epoch 120, CIFAR-10 Batch 2:  loss :0.0validation accuracy :0.558
# Epoch 120, CIFAR-10 Batch 3:  loss :0.0validation accuracy :0.5562
# Epoch 120, CIFAR-10 Batch 4:  loss :0.0validation accuracy :0.5564
# Epoch 120, CIFAR-10 Batch 5:  loss :0.0validation accuracy :0.5556
# Epoch 121, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.5724
# Epoch 121, CIFAR-10 Batch 2:  loss :0.0validation accuracy :0.5608
# Epoch 121, CIFAR-10 Batch 3:  loss :0.0validation accuracy :0.5604
# Epoch 121, CIFAR-10 Batch 4:  loss :0.0validation accuracy :0.5662
# Epoch 121, CIFAR-10 Batch 5:  loss :0.0validation accuracy :0.5544
# Epoch 122, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.5622
# Epoch 122, CIFAR-10 Batch 2:  loss :0.0validation accuracy :0.5522
# Epoch 122, CIFAR-10 Batch 3:  loss :0.0validation accuracy :0.548
# Epoch 122, CIFAR-10 Batch 4:  loss :150.897validation accuracy :0.5546
# Epoch 122, CIFAR-10 Batch 5:  loss :0.0validation accuracy :0.5548
# Epoch 123, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.5532
# Epoch 123, CIFAR-10 Batch 2:  loss :0.0validation accuracy :0.5512
# Epoch 123, CIFAR-10 Batch 3:  loss :0.0validation accuracy :0.5528
# Epoch 123, CIFAR-10 Batch 4:  loss :0.0validation accuracy :0.5472
# Epoch 123, CIFAR-10 Batch 5:  loss :0.0validation accuracy :0.5574
# Epoch 124, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.5436
# Epoch 124, CIFAR-10 Batch 2:  loss :0.0validation accuracy :0.551
# Epoch 124, CIFAR-10 Batch 3:  loss :0.0validation accuracy :0.5512
# Epoch 124, CIFAR-10 Batch 4:  loss :0.0validation accuracy :0.5464
# Epoch 124, CIFAR-10 Batch 5:  loss :0.0validation accuracy :0.5576
# Epoch 125, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.5576
# Epoch 125, CIFAR-10 Batch 2:  loss :0.0validation accuracy :0.5494
# Epoch 125, CIFAR-10 Batch 3:  loss :0.0validation accuracy :0.554
# Epoch 125, CIFAR-10 Batch 4:  loss :0.0validation accuracy :0.5436
# Epoch 125, CIFAR-10 Batch 5:  loss :0.0validation accuracy :0.552
# Epoch 126, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.555
# Epoch 126, CIFAR-10 Batch 2:  loss :0.0validation accuracy :0.547
# Epoch 126, CIFAR-10 Batch 3:  loss :0.0validation accuracy :0.5502
# Epoch 126, CIFAR-10 Batch 4:  loss :0.0validation accuracy :0.5502
# Epoch 126, CIFAR-10 Batch 5:  loss :0.0validation accuracy :0.5562
# Epoch 127, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.5468
# Epoch 127, CIFAR-10 Batch 2:  loss :0.0validation accuracy :0.5576
# Epoch 127, CIFAR-10 Batch 3:  loss :0.0validation accuracy :0.548
# Epoch 127, CIFAR-10 Batch 4:  loss :0.0validation accuracy :0.5556
# Epoch 127, CIFAR-10 Batch 5:  loss :0.0validation accuracy :0.5506
# Epoch 128, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.5528
# Epoch 128, CIFAR-10 Batch 2:  loss :0.0validation accuracy :0.5542
# Epoch 128, CIFAR-10 Batch 3:  loss :0.0validation accuracy :0.5604
# Epoch 128, CIFAR-10 Batch 4:  loss :0.0validation accuracy :0.5468
# Epoch 128, CIFAR-10 Batch 5:  loss :0.0validation accuracy :0.5622
# Epoch 129, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.564
# Epoch 129, CIFAR-10 Batch 2:  loss :0.0validation accuracy :0.5626
# Epoch 129, CIFAR-10 Batch 3:  loss :0.0validation accuracy :0.5602
# Epoch 129, CIFAR-10 Batch 4:  loss :0.0validation accuracy :0.5504
# Epoch 129, CIFAR-10 Batch 5:  loss :0.0validation accuracy :0.5648
# Epoch 130, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.5622
# Epoch 130, CIFAR-10 Batch 2:  loss :0.0validation accuracy :0.5588
# Epoch 130, CIFAR-10 Batch 3:  loss :0.0validation accuracy :0.5616
# Epoch 130, CIFAR-10 Batch 4:  loss :0.0validation accuracy :0.5478
# Epoch 130, CIFAR-10 Batch 5:  loss :45.6889validation accuracy :0.5554
# Epoch 131, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.5618
# Epoch 131, CIFAR-10 Batch 2:  loss :0.0validation accuracy :0.5592
# Epoch 131, CIFAR-10 Batch 3:  loss :0.0validation accuracy :0.558
# Epoch 131, CIFAR-10 Batch 4:  loss :0.0validation accuracy :0.55
# Epoch 131, CIFAR-10 Batch 5:  loss :0.0validation accuracy :0.5582
# Epoch 132, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.5514
# Epoch 132, CIFAR-10 Batch 2:  loss :0.0validation accuracy :0.5576
# Epoch 132, CIFAR-10 Batch 3:  loss :0.0validation accuracy :0.562
# Epoch 132, CIFAR-10 Batch 4:  loss :0.0validation accuracy :0.5518
# Epoch 132, CIFAR-10 Batch 5:  loss :0.0validation accuracy :0.5602
# Epoch 133, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.5634
# Epoch 133, CIFAR-10 Batch 2:  loss :0.0validation accuracy :0.563
# Epoch 133, CIFAR-10 Batch 3:  loss :0.0validation accuracy :0.5608
# Epoch 133, CIFAR-10 Batch 4:  loss :0.0validation accuracy :0.564
# Epoch 133, CIFAR-10 Batch 5:  loss :0.0validation accuracy :0.5728
# Epoch 134, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.5572
# Epoch 134, CIFAR-10 Batch 2:  loss :0.0validation accuracy :0.5632
# Epoch 134, CIFAR-10 Batch 3:  loss :0.0validation accuracy :0.5604
# Epoch 134, CIFAR-10 Batch 4:  loss :0.0validation accuracy :0.5588
# Epoch 134, CIFAR-10 Batch 5:  loss :0.0validation accuracy :0.5658
# Epoch 135, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.5538
# Epoch 135, CIFAR-10 Batch 2:  loss :0.0validation accuracy :0.5644
# Epoch 135, CIFAR-10 Batch 3:  loss :0.0validation accuracy :0.5576
# Epoch 135, CIFAR-10 Batch 4:  loss :0.0validation accuracy :0.5546
# Epoch 135, CIFAR-10 Batch 5:  loss :0.0validation accuracy :0.5474
# Epoch 136, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.558
# Epoch 136, CIFAR-10 Batch 2:  loss :0.0validation accuracy :0.5562
# Epoch 136, CIFAR-10 Batch 3:  loss :0.0validation accuracy :0.5568
# Epoch 136, CIFAR-10 Batch 4:  loss :0.0validation accuracy :0.5558
# Epoch 136, CIFAR-10 Batch 5:  loss :0.0validation accuracy :0.567
# Epoch 137, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.5614
# Epoch 137, CIFAR-10 Batch 2:  loss :0.0validation accuracy :0.554
# Epoch 137, CIFAR-10 Batch 3:  loss :0.0validation accuracy :0.5502
# Epoch 137, CIFAR-10 Batch 4:  loss :1324.82validation accuracy :0.5546
# Epoch 137, CIFAR-10 Batch 5:  loss :0.0validation accuracy :0.5614
# Epoch 138, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.5578
# Epoch 138, CIFAR-10 Batch 2:  loss :0.0validation accuracy :0.5506
# Epoch 138, CIFAR-10 Batch 3:  loss :0.0validation accuracy :0.557
# Epoch 138, CIFAR-10 Batch 4:  loss :0.0validation accuracy :0.5554
# Epoch 138, CIFAR-10 Batch 5:  loss :0.0validation accuracy :0.568
# Epoch 139, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.5568
# Epoch 139, CIFAR-10 Batch 2:  loss :0.0validation accuracy :0.5462
# Epoch 139, CIFAR-10 Batch 3:  loss :0.0validation accuracy :0.5584
# Epoch 139, CIFAR-10 Batch 4:  loss :0.0validation accuracy :0.5532
# Epoch 139, CIFAR-10 Batch 5:  loss :0.0validation accuracy :0.5654
# Epoch 140, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.5656
# Epoch 140, CIFAR-10 Batch 2:  loss :0.0validation accuracy :0.5564
# Epoch 140, CIFAR-10 Batch 3:  loss :0.0validation accuracy :0.5668
# Epoch 140, CIFAR-10 Batch 4:  loss :0.0validation accuracy :0.5664
# Epoch 140, CIFAR-10 Batch 5:  loss :0.0validation accuracy :0.5642
# Epoch 141, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.5774
# Epoch 141, CIFAR-10 Batch 2:  loss :0.0validation accuracy :0.5566
# Epoch 141, CIFAR-10 Batch 3:  loss :0.0validation accuracy :0.5636
# Epoch 141, CIFAR-10 Batch 4:  loss :0.0validation accuracy :0.5648
# Epoch 141, CIFAR-10 Batch 5:  loss :0.0validation accuracy :0.567
# Epoch 142, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.5624
# Epoch 142, CIFAR-10 Batch 2:  loss :0.0validation accuracy :0.5616
# Epoch 142, CIFAR-10 Batch 3:  loss :0.0validation accuracy :0.5626
# Epoch 142, CIFAR-10 Batch 4:  loss :0.0validation accuracy :0.5602
# Epoch 142, CIFAR-10 Batch 5:  loss :0.0validation accuracy :0.5598
# Epoch 143, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.568
# Epoch 143, CIFAR-10 Batch 2:  loss :0.0validation accuracy :0.5598
# Epoch 143, CIFAR-10 Batch 3:  loss :0.0validation accuracy :0.565
# Epoch 143, CIFAR-10 Batch 4:  loss :0.0validation accuracy :0.5642
# ...
# Epoch 153, CIFAR-10 Batch 2:  loss :0.0validation accuracy :0.5666
# Epoch 153, CIFAR-10 Batch 3:  loss :0.0validation accuracy :0.5568
# Epoch 153, CIFAR-10 Batch 4:  loss :0.0validation accuracy :0.5592
# Epoch 153, CIFAR-10 Batch 5:  loss :0.0validation accuracy :0.558
# Epoch 154, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.5598
# Epoch 154, CIFAR-10 Batch 2:  loss :0.0validation accuracy :0.5628
# Epoch 154, CIFAR-10 Batch 3:  loss :0.0validation accuracy :0.5666
# Epoch 154, CIFAR-10 Batch 4:  loss :0.0validation accuracy :0.561
# Epoch 154, CIFAR-10 Batch 5:  loss :0.0validation accuracy :0.5606
# Epoch 155, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.5536
# Epoch 155, CIFAR-10 Batch 2:  loss :0.0validation accuracy :0.5604
# Epoch 155, CIFAR-10 Batch 3:  loss :0.0validation accuracy :0.564
# Epoch 155, CIFAR-10 Batch 4:  loss :0.0validation accuracy :0.5512
# Epoch 155, CIFAR-10 Batch 5:  loss :0.0validation accuracy :0.562
# Epoch 156, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.5562
# Epoch 156, CIFAR-10 Batch 2:  loss :0.0validation accuracy :0.5674
# Epoch 156, CIFAR-10 Batch 3:  loss :0.0validation accuracy :0.5658
# Epoch 156, CIFAR-10 Batch 4:  loss :0.0validation accuracy :0.5672
# Epoch 156, CIFAR-10 Batch 5:  loss :0.0validation accuracy :0.559
# Epoch 157, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.57
# Epoch 157, CIFAR-10 Batch 2:  loss :0.0validation accuracy :0.567
# Epoch 157, CIFAR-10 Batch 3:  loss :0.0validation accuracy :0.5598
# Epoch 157, CIFAR-10 Batch 4:  loss :0.0validation accuracy :0.5606
# Epoch 157, CIFAR-10 Batch 5:  loss :0.0validation accuracy :0.5664
# Epoch 158, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.5696
# Epoch 158, CIFAR-10 Batch 2:  loss :0.0validation accuracy :0.5596
# Epoch 158, CIFAR-10 Batch 3:  loss :0.0validation accuracy :0.5644
# Epoch 158, CIFAR-10 Batch 4:  loss :0.0validation accuracy :0.5578
# Epoch 158, CIFAR-10 Batch 5:  loss :0.0validation accuracy :0.5674
# Epoch 159, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.565
# Epoch 159, CIFAR-10 Batch 2:  loss :0.0validation accuracy :0.5598
# Epoch 159, CIFAR-10 Batch 3:  loss :0.0validation accuracy :0.5658
# Epoch 159, CIFAR-10 Batch 4:  loss :0.0validation accuracy :0.561
# Epoch 159, CIFAR-10 Batch 5:  loss :0.0validation accuracy :0.5642
# Epoch 160, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.5608
# Epoch 160, CIFAR-10 Batch 2:  loss :0.0validation accuracy :0.561
# Epoch 160, CIFAR-10 Batch 3:  loss :0.0validation accuracy :0.5682
# Epoch 160, CIFAR-10 Batch 4:  loss :0.0validation accuracy :0.5718
# Epoch 160, CIFAR-10 Batch 5:  loss :0.0validation accuracy :0.5596
# Epoch 161, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.5652
# Epoch 161, CIFAR-10 Batch 2:  loss :0.0validation accuracy :0.5642
# Epoch 161, CIFAR-10 Batch 3:  loss :0.0validation accuracy :0.5646
# Epoch 161, CIFAR-10 Batch 4:  loss :0.0validation accuracy :0.5686
# Epoch 161, CIFAR-10 Batch 5:  loss :0.0validation accuracy :0.5694
# Epoch 162, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.571
# Epoch 162, CIFAR-10 Batch 2:  loss :0.0validation accuracy :0.5636
# Epoch 162, CIFAR-10 Batch 3:  loss :0.0validation accuracy :0.5668
# Epoch 162, CIFAR-10 Batch 4:  loss :0.0validation accuracy :0.565
# Epoch 162, CIFAR-10 Batch 5:  loss :0.0validation accuracy :0.561
# Epoch 163, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.561
# Epoch 163, CIFAR-10 Batch 2:  loss :0.0validation accuracy :0.5668
# Epoch 163, CIFAR-10 Batch 3:  loss :0.0validation accuracy :0.5706
# Epoch 163, CIFAR-10 Batch 4:  loss :0.0validation accuracy :0.5678
# Epoch 163, CIFAR-10 Batch 5:  loss :0.0validation accuracy :0.574
# Epoch 164, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.5662
# Epoch 164, CIFAR-10 Batch 2:  loss :0.0validation accuracy :0.573
# Epoch 164, CIFAR-10 Batch 3:  loss :0.0validation accuracy :0.5594
# Epoch 164, CIFAR-10 Batch 4:  loss :0.0validation accuracy :0.5634
# Epoch 164, CIFAR-10 Batch 5:  loss :0.0validation accuracy :0.5682
# Epoch 165, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.5714
# Epoch 165, CIFAR-10 Batch 2:  loss :0.0validation accuracy :0.559
# Epoch 165, CIFAR-10 Batch 3:  loss :0.0validation accuracy :0.5608
# Epoch 165, CIFAR-10 Batch 4:  loss :0.0validation accuracy :0.5704
# Epoch 165, CIFAR-10 Batch 5:  loss :0.0validation accuracy :0.5644
# Epoch 166, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.5744
# Epoch 166, CIFAR-10 Batch 2:  loss :0.0validation accuracy :0.5596
# Epoch 166, CIFAR-10 Batch 3:  loss :0.0validation accuracy :0.566
# Epoch 166, CIFAR-10 Batch 4:  loss :0.0validation accuracy :0.5694
# Epoch 166, CIFAR-10 Batch 5:  loss :0.0validation accuracy :0.5654
# Epoch 167, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.572
# Epoch 167, CIFAR-10 Batch 2:  loss :0.0validation accuracy :0.5666
# Epoch 167, CIFAR-10 Batch 3:  loss :0.0validation accuracy :0.57
# Epoch 167, CIFAR-10 Batch 4:  loss :0.0validation accuracy :0.573
# Epoch 167, CIFAR-10 Batch 5:  loss :0.0validation accuracy :0.5728
# Epoch 168, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.576
# Epoch 168, CIFAR-10 Batch 2:  loss :0.0validation accuracy :0.567
# Epoch 168, CIFAR-10 Batch 3:  loss :0.0validation accuracy :0.5702
# Epoch 168, CIFAR-10 Batch 4:  loss :0.0validation accuracy :0.5646
# Epoch 168, CIFAR-10 Batch 5:  loss :0.0validation accuracy :0.5632
# Epoch 169, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.568
# Epoch 169, CIFAR-10 Batch 2:  loss :0.0validation accuracy :0.56
# Epoch 169, CIFAR-10 Batch 3:  loss :0.0validation accuracy :0.568
# Epoch 169, CIFAR-10 Batch 4:  loss :0.0validation accuracy :0.5588
# Epoch 169, CIFAR-10 Batch 5:  loss :0.0validation accuracy :0.5716
# Epoch 170, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.5682
# Epoch 170, CIFAR-10 Batch 2:  loss :0.0validation accuracy :0.568
# Epoch 170, CIFAR-10 Batch 3:  loss :0.0validation accuracy :0.57
# Epoch 170, CIFAR-10 Batch 4:  loss :0.0validation accuracy :0.5634
# Epoch 170, CIFAR-10 Batch 5:  loss :0.0validation accuracy :0.5658
# Epoch 171, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.5688
# Epoch 171, CIFAR-10 Batch 2:  loss :0.0validation accuracy :0.564
# Epoch 171, CIFAR-10 Batch 3:  loss :0.0validation accuracy :0.5678
# Epoch 171, CIFAR-10 Batch 4:  loss :0.0validation accuracy :0.5644
# Epoch 171, CIFAR-10 Batch 5:  loss :0.0validation accuracy :0.5574
# Epoch 172, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.56
# Epoch 172, CIFAR-10 Batch 2:  loss :0.0validation accuracy :0.558
# Epoch 172, CIFAR-10 Batch 3:  loss :0.0validation accuracy :0.5536
# Epoch 172, CIFAR-10 Batch 4:  loss :0.0validation accuracy :0.566
# Epoch 172, CIFAR-10 Batch 5:  loss :0.0validation accuracy :0.5764
# Epoch 173, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.5674
# Epoch 173, CIFAR-10 Batch 2:  loss :0.0validation accuracy :0.5632
# Epoch 173, CIFAR-10 Batch 3:  loss :0.0validation accuracy :0.5676
# Epoch 173, CIFAR-10 Batch 4:  loss :0.0validation accuracy :0.5544
# Epoch 173, CIFAR-10 Batch 5:  loss :0.0validation accuracy :0.5686
# Epoch 174, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.5726
# Epoch 174, CIFAR-10 Batch 2:  loss :0.0validation accuracy :0.5744
# Epoch 174, CIFAR-10 Batch 3:  loss :0.0validation accuracy :0.5636
# Epoch 174, CIFAR-10 Batch 4:  loss :0.0validation accuracy :0.5678
# Epoch 174, CIFAR-10 Batch 5:  loss :0.0validation accuracy :0.5654
# Epoch 175, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.5614
# Epoch 175, CIFAR-10 Batch 2:  loss :0.0validation accuracy :0.568
# Epoch 175, CIFAR-10 Batch 3:  loss :0.0validation accuracy :0.5574
# Epoch 175, CIFAR-10 Batch 4:  loss :0.0validation accuracy :0.5546
# Epoch 175, CIFAR-10 Batch 5:  loss :0.0validation accuracy :0.5658
# Epoch 176, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.5648
# Epoch 176, CIFAR-10 Batch 2:  loss :0.0validation accuracy :0.562
# Epoch 176, CIFAR-10 Batch 3:  loss :0.0validation accuracy :0.5594
# Epoch 176, CIFAR-10 Batch 4:  loss :0.0validation accuracy :0.5738
# Epoch 176, CIFAR-10 Batch 5:  loss :0.0validation accuracy :0.5736
# Epoch 177, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.567
# Epoch 177, CIFAR-10 Batch 2:  loss :0.0validation accuracy :0.571
# Epoch 177, CIFAR-10 Batch 3:  loss :0.0validation accuracy :0.5642
# Epoch 177, CIFAR-10 Batch 4:  loss :0.0validation accuracy :0.5666
# Epoch 177, CIFAR-10 Batch 5:  loss :0.0validation accuracy :0.5724
# Epoch 178, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.5656
# Epoch 178, CIFAR-10 Batch 2:  loss :0.0validation accuracy :0.5598
# Epoch 178, CIFAR-10 Batch 3:  loss :0.0validation accuracy :0.5596
# Epoch 178, CIFAR-10 Batch 4:  loss :0.0validation accuracy :0.55
# Epoch 178, CIFAR-10 Batch 5:  loss :0.0validation accuracy :0.568
# Epoch 179, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.5582
# Epoch 179, CIFAR-10 Batch 2:  loss :0.0validation accuracy :0.5686
# Epoch 179, CIFAR-10 Batch 3:  loss :0.0validation accuracy :0.561
# Epoch 179, CIFAR-10 Batch 4:  loss :0.0validation accuracy :0.5642
# Epoch 179, CIFAR-10 Batch 5:  loss :0.0validation accuracy :0.5714
# Epoch 180, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.5678
# Epoch 180, CIFAR-10 Batch 2:  loss :0.0validation accuracy :0.569
# Epoch 180, CIFAR-10 Batch 3:  loss :0.0validation accuracy :0.567
# Epoch 180, CIFAR-10 Batch 4:  loss :0.0validation accuracy :0.5578
# Epoch 180, CIFAR-10 Batch 5:  loss :0.0validation accuracy :0.568
# Epoch 181, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.5642
# Epoch 181, CIFAR-10 Batch 2:  loss :0.0validation accuracy :0.5744
# Epoch 181, CIFAR-10 Batch 3:  loss :0.0validation accuracy :0.571
# Epoch 181, CIFAR-10 Batch 4:  loss :0.0validation accuracy :0.5738
# Epoch 181, CIFAR-10 Batch 5:  loss :0.0validation accuracy :0.5636
# Epoch 182, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.5714
# Epoch 182, CIFAR-10 Batch 2:  loss :0.0validation accuracy :0.5684
# Epoch 182, CIFAR-10 Batch 3:  loss :0.0validation accuracy :0.5692
# Epoch 182, CIFAR-10 Batch 4:  loss :0.0validation accuracy :0.5692
# Epoch 182, CIFAR-10 Batch 5:  loss :0.0validation accuracy :0.572
# Epoch 183, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.5686
# Epoch 183, CIFAR-10 Batch 2:  loss :0.0validation accuracy :0.5588
# Epoch 183, CIFAR-10 Batch 3:  loss :0.0validation accuracy :0.5612
# Epoch 183, CIFAR-10 Batch 4:  loss :0.0validation accuracy :0.5656
# Epoch 183, CIFAR-10 Batch 5:  loss :0.0validation accuracy :0.5642
# Epoch 184, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.571
# Epoch 184, CIFAR-10 Batch 2:  loss :0.0validation accuracy :0.5644
# Epoch 184, CIFAR-10 Batch 3:  loss :0.0validation accuracy :0.5638
# Epoch 184, CIFAR-10 Batch 4:  loss :0.0validation accuracy :0.5718
# Epoch 184, CIFAR-10 Batch 5:  loss :0.0validation accuracy :0.567
# Epoch 185, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.5758
# Epoch 185, CIFAR-10 Batch 2:  loss :0.0validation accuracy :0.5668
# Epoch 185, CIFAR-10 Batch 3:  loss :0.0validation accuracy :0.573
# Epoch 185, CIFAR-10 Batch 4:  loss :0.0validation accuracy :0.5642
# Epoch 185, CIFAR-10 Batch 5:  loss :0.0validation accuracy :0.5662
# Epoch 186, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.5706
# Epoch 186, CIFAR-10 Batch 2:  loss :0.0validation accuracy :0.5646
# Epoch 186, CIFAR-10 Batch 3:  loss :0.0validation accuracy :0.5618
# Epoch 186, CIFAR-10 Batch 4:  loss :0.0validation accuracy :0.566
# Epoch 186, CIFAR-10 Batch 5:  loss :0.0validation accuracy :0.5646
# Epoch 187, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.5738
# Epoch 187, CIFAR-10 Batch 2:  loss :0.0validation accuracy :0.568
# Epoch 187, CIFAR-10 Batch 3:  loss :0.0validation accuracy :0.574
# Epoch 187, CIFAR-10 Batch 4:  loss :0.0validation accuracy :0.5686
# Epoch 187, CIFAR-10 Batch 5:  loss :0.0validation accuracy :0.5676
# Epoch 188, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.5718
# Epoch 188, CIFAR-10 Batch 2:  loss :0.0validation accuracy :0.5694
# Epoch 188, CIFAR-10 Batch 3:  loss :0.0validation accuracy :0.5636
# Epoch 188, CIFAR-10 Batch 4:  loss :0.0validation accuracy :0.5748
# Epoch 188, CIFAR-10 Batch 5:  loss :0.0validation accuracy :0.5722
# Epoch 189, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.5654
# Epoch 189, CIFAR-10 Batch 2:  loss :0.0validation accuracy :0.577
# Epoch 189, CIFAR-10 Batch 3:  loss :0.0validation accuracy :0.566
# Epoch 189, CIFAR-10 Batch 4:  loss :0.0validation accuracy :0.5716
# Epoch 189, CIFAR-10 Batch 5:  loss :0.0validation accuracy :0.5638
# Epoch 190, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.5766
# Epoch 190, CIFAR-10 Batch 2:  loss :0.0validation accuracy :0.566
# Epoch 190, CIFAR-10 Batch 3:  loss :0.0validation accuracy :0.5644
# Epoch 190, CIFAR-10 Batch 4:  loss :0.0validation accuracy :0.5604
# Epoch 190, CIFAR-10 Batch 5:  loss :0.0validation accuracy :0.5694
# Epoch 191, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.569
# Epoch 191, CIFAR-10 Batch 2:  loss :0.0validation accuracy :0.5704
# Epoch 191, CIFAR-10 Batch 3:  loss :0.0validation accuracy :0.571
# Epoch 191, CIFAR-10 Batch 4:  loss :0.0validation accuracy :0.5728
# Epoch 191, CIFAR-10 Batch 5:  loss :0.0validation accuracy :0.5604
# Epoch 192, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.561
# Epoch 192, CIFAR-10 Batch 2:  loss :0.0validation accuracy :0.57
# Epoch 192, CIFAR-10 Batch 3:  loss :0.0validation accuracy :0.565
# Epoch 192, CIFAR-10 Batch 4:  loss :0.0validation accuracy :0.5666
# Epoch 192, CIFAR-10 Batch 5:  loss :0.0validation accuracy :0.5716
# Epoch 193, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.5814
# Epoch 193, CIFAR-10 Batch 2:  loss :0.0validation accuracy :0.5706
# Epoch 193, CIFAR-10 Batch 3:  loss :0.0validation accuracy :0.5612
# Epoch 193, CIFAR-10 Batch 4:  loss :0.0validation accuracy :0.5766
# Epoch 193, CIFAR-10 Batch 5:  loss :0.0validation accuracy :0.5734
# Epoch 194, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.5784
# Epoch 194, CIFAR-10 Batch 2:  loss :0.0validation accuracy :0.569
# Epoch 194, CIFAR-10 Batch 3:  loss :0.0validation accuracy :0.5634
# Epoch 194, CIFAR-10 Batch 4:  loss :0.0validation accuracy :0.5704
# Epoch 194, CIFAR-10 Batch 5:  loss :0.0validation accuracy :0.5642
# Epoch 195, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.5774
# Epoch 195, CIFAR-10 Batch 2:  loss :0.0validation accuracy :0.5832
# Epoch 195, CIFAR-10 Batch 3:  loss :0.0validation accuracy :0.5684
# Epoch 195, CIFAR-10 Batch 4:  loss :0.0validation accuracy :0.5664
# Epoch 195, CIFAR-10 Batch 5:  loss :0.0validation accuracy :0.5694
# Epoch 196, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.5746
# Epoch 196, CIFAR-10 Batch 2:  loss :0.0validation accuracy :0.5704
# Epoch 196, CIFAR-10 Batch 3:  loss :0.0validation accuracy :0.5654
# Epoch 196, CIFAR-10 Batch 4:  loss :0.0validation accuracy :0.5746
# Epoch 196, CIFAR-10 Batch 5:  loss :0.0validation accuracy :0.5638
# Epoch 197, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.5804
# Epoch 197, CIFAR-10 Batch 2:  loss :0.0validation accuracy :0.5708
# Epoch 197, CIFAR-10 Batch 3:  loss :0.0validation accuracy :0.572
# Epoch 197, CIFAR-10 Batch 4:  loss :0.0validation accuracy :0.5664
# Epoch 197, CIFAR-10 Batch 5:  loss :0.0validation accuracy :0.5746
# Epoch 198, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.5748
# Epoch 198, CIFAR-10 Batch 2:  loss :0.0validation accuracy :0.5682
# Epoch 198, CIFAR-10 Batch 3:  loss :0.0validation accuracy :0.5666
# Epoch 198, CIFAR-10 Batch 4:  loss :0.0validation accuracy :0.572
# Epoch 198, CIFAR-10 Batch 5:  loss :0.0validation accuracy :0.5742
# Epoch 199, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.5804
# Epoch 199, CIFAR-10 Batch 2:  loss :0.0validation accuracy :0.5702
# Epoch 199, CIFAR-10 Batch 3:  loss :0.0validation accuracy :0.5728
# Epoch 199, CIFAR-10 Batch 4:  loss :0.0validation accuracy :0.5698
# Epoch 199, CIFAR-10 Batch 5:  loss :0.0validation accuracy :0.5826
# Epoch 200, CIFAR-10 Batch 1:  loss :0.0validation accuracy :0.5694
# Epoch 200, CIFAR-10 Batch 2:  loss :0.0validation accuracy :0.5834
# Epoch 200, CIFAR-10 Batch 3:  loss :0.0validation accuracy :0.5798
# Epoch 200, CIFAR-10 Batch 4:  loss :0.0validation accuracy :0.574
# Epoch 200, CIFAR-10 Batch 5:  loss :0.0validation accuracy :0.5724

# %% [markdown]
# # Checkpoint
# The model has been saved to disk.
# ## Test Model
# Test your model against the test dataset.  This will be your final accuracy. You should have an accuracy greater than 50%. If you don't, keep tweaking the model architecture and parameters.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import tensorflow as tf
import pickle
import helper
import random

# Set batch size if not already set
try:
    if batch_size:
        pass
except NameError:
    batch_size = 64

save_model_path = './image_classification'
n_samples = 4
top_n_predictions = 3

def test_model():
    """
    Test the saved model against the test dataset
    """

    test_features, test_labels = pickle.load(open('preprocess_test.p', mode='rb'))
    loaded_graph = tf.Graph()

    with tf.Session(graph=loaded_graph) as sess:
        # Load model
        loader = tf.train.import_meta_graph(save_model_path + '.meta')
        loader.restore(sess, save_model_path)

        # Get Tensors from loaded model
        loaded_x = loaded_graph.get_tensor_by_name('x:0')
        loaded_y = loaded_graph.get_tensor_by_name('y:0')
        loaded_keep_prob = loaded_graph.get_tensor_by_name('keep_prob:0')
        loaded_logits = loaded_graph.get_tensor_by_name('logits:0')
        loaded_acc = loaded_graph.get_tensor_by_name('accuracy:0')
        
        # Get accuracy in batches for memory limitations
        test_batch_acc_total = 0
        test_batch_count = 0
        
        for test_feature_batch, test_label_batch in helper.batch_features_labels(test_features, test_labels, batch_size):
            test_batch_acc_total += sess.run(
                loaded_acc,
                feed_dict={loaded_x: test_feature_batch, loaded_y: test_label_batch, loaded_keep_prob: 1.0})
            test_batch_count += 1

        print('Testing Accuracy: {}\n'.format(test_batch_acc_total/test_batch_count))

        # Print Random Samples
        random_test_features, random_test_labels = tuple(zip(*random.sample(list(zip(test_features, test_labels)), n_samples)))
        random_test_predictions = sess.run(
            tf.nn.top_k(tf.nn.softmax(loaded_logits), top_n_predictions),
            feed_dict={loaded_x: random_test_features, loaded_y: random_test_labels, loaded_keep_prob: 1.0})
        helper.display_image_predictions(random_test_features, random_test_labels, random_test_predictions)


test_model()
# Out:
# INFO:tensorflow:Restoring parameters from ./image_classification
# Testing Accuracy: 0.5597310126582279

# %% [markdown]
# ## Why 50-80% Accuracy?
# You might be wondering why you can't get an accuracy any higher. First things first, 50% isn't bad for a simple CNN.  Pure guessing would get you 10% accuracy. However, you might notice people are getting scores [well above 80%](http://rodrigob.github.io/are_we_there_yet/build/classification_datasets_results.html#43494641522d3130).  That's because we haven't taught you all there is to know about neural networks. We still need to cover a few more techniques.
# ## Submitting This Project
# When submitting this project, make sure to run all the cells before saving the notebook.  Save the notebook file as "dlnd_image_classification.ipynb" and save it as a HTML file under "File" -> "Download as".  Include the "helper.py" and "problem_unittests.py" files in your submission.
